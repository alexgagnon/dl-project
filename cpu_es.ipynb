# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import itertools
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
def calc_params(w,l):
    num_params = 784*w
    for i in range(l-2):
        num_params += w*w
    num_params += w*10
    return num_params

def get_width(percent):
    num_params = calc_params(128,2)/percent
    a = 2 #l?
    width = (-794+np.sqrt(794**2+4*a*num_params))/(2*a)
    return int(width)

print("Percent of Overparametrized Network")
print("W = 128:",calc_params(128,2)/calc_params(128,4))
print("W = 256:",calc_params(128,2)/calc_params(256,4))
print("W = 512:",calc_params(128,2)/calc_params(512,4))
print("W = 1024:",calc_params(128,2)/calc_params(1024,4))

print("\nWidth of Overparametrized Network (Twice as Deep)")
print("10%:",get_width(0.1))
print("20%:",get_width(0.2))
print("30%:",get_width(0.3))
print("40%:",get_width(0.4))
print("50%:",get_width(0.5))
# Out:
# Percent of Overparametrized Network
# W = 128: 0.7561904761904762
# W = 256: 0.30398162327718226
# W = 512: 0.10918591859185918
# W = 1024: 0.03492258972554539
#
# Width of Overparametrized Network (Twice as Deep)
# 10%: 541
# 20%: 343
# 30%: 258
# 40%: 209
# 50%: 177

# %% [markdown]
# MLP Model

# %%
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(MLP, self).__init__()

        # Check if number of layers is at least 1
        if num_layers < 1:
            raise ValueError("Number of layers must be at least 1")

        layers = []

        # First layer
        layers.append(nn.Linear(input_size, hidden_size, bias=False))

        # Additional hidden layers
        for _ in range(1, num_layers):
            layers.append(nn.Linear(hidden_size, hidden_size, bias=False))

        # Output layer
        layers.append(nn.Linear(hidden_size, output_size, bias=False))

        # ModuleList of layers
        self.layers = nn.ModuleList(layers)

    def forward(self, x):
        x = x.view(-1, 28*28)  # Flatten the input

        # Apply all layers except the last
        for layer in self.layers[:-1]:
            x = torch.relu(layer(x))

        # Apply the last layer without ReLU
        x = self.layers[-1](x)

        return x

# %% [markdown]
# Helper Functions

# %%
def evaluate(model, test_loader):
    model.eval()
    model.to(device)  # Move the model to the configured device
    correct = 0
    total = 0
    loss = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            batch_loss = torch.nn.CrossEntropyLoss()(outputs, labels)
            loss += batch_loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    test_accuracy = 100 * correct / total
    test_loss = loss / total
    return test_accuracy, test_loss

def evaluate_masked_model_loss_and_accuracy(model, concatenated_mask, initial_weights, test_loader, criterion, num_batches=1):

    # Split the concatenated mask back into individual masks
    split_indices = np.cumsum([len(w.flatten()) for w in initial_weights[:-1]])
    masks = np.split(concatenated_mask, split_indices)

    # Reshape each mask to match the corresponding weight matrix
    for j, w in enumerate(initial_weights):
        masks[j] = masks[j].reshape(w.shape)

    # Apply the mask to the initial weights
    masked_weights = [w * m for w, m in zip(initial_weights, masks)]

    # Set the masked weights to the model
    with torch.no_grad():
        for param, weight in zip(model.parameters(), masked_weights):
            param.data = torch.tensor(weight).float()

    # Evaluate the model's performance using a subset of the test data
    accuracy, loss = evaluate(model, itertools.islice(test_loader, num_batches))

    return accuracy, loss

def sort_and_evaluate_masks(mask_pop, model, initial_weights, test_loader, criterion, num_batches, print_results=False):
    performance = []

    for i, mask in enumerate(mask_pop):
        accuracy, avg_test_loss = evaluate_masked_model_loss_and_accuracy(model, mask, initial_weights, test_loader, criterion, num_batches)
        performance.append((mask, accuracy, avg_test_loss))

    # Sort by accuracy (descending)
    #-x[2] -> sort by loss, x[1] -> accuracy
    sorted_performance = sorted(performance, key=lambda x: x[1], reverse=True)

    # Print sorted results
    if print_results:
        for i, (mask, accuracy, avg_test_loss) in enumerate(sorted_performance):
            print(f"Ranked {i+1}, Mask {i}: Test Accuracy = {accuracy:.2f}%, Test Loss = {avg_test_loss:.4f}")

    # Return sorted mask population
    sorted_mask_pop = [mask for mask, _, _ in sorted_performance]
    sorted_accuracies = [accuracy for _, accuracy, _ in sorted_performance]
    sorted_losses = [loss for _, _, loss in sorted_performance]
    return sorted_mask_pop, sorted_accuracies, sorted_losses

def evaluate_mask_sizes(mask_pop):
    total_weights = sum(w.size for w in mask_pop[0])
    mask_sizes = []

    for masks in mask_pop:
        non_zero_weights = sum(np.count_nonzero(m) for m in masks)
        mask_size_percentage = (non_zero_weights / total_weights) * 100
        mask_sizes.append(mask_size_percentage)

    return mask_sizes

# %% [markdown]
# Evolution

# %%
def initialize_masks(weights,target_params,num_subnets=10):

    # Flatten and concatenate all weight matrices
    concatenated_weights = np.concatenate([w.flatten() for w in weights])

    # Determine number of weights to zero out
    num_zero_out = int(len(concatenated_weights)-target_params)
    mask_pop = []

    for i in range(num_subnets):

        # Randomly choose indices to zero out
        zero_indices = np.random.choice(len(concatenated_weights), num_zero_out, replace=False)

        # Create a mask for concatenated weights
        concatenated_mask = np.ones_like(concatenated_weights)
        concatenated_mask[zero_indices] = 0

        #add to population
        mask_pop.append(concatenated_mask)

    return mask_pop

def mutate_mask(mask, m):

    mutated_mask = mask.copy()

    # Get the indices of ones and zeros
    one_indices = np.where(mutated_mask == 1)[0]
    zero_indices = np.where(mutated_mask == 0)[0]

    # Randomly select m ones and zeros to switch
    selected_ones = np.random.choice(one_indices, m, replace=False)
    selected_zeros = np.random.choice(zero_indices, m, replace=False)

    # Switch selected ones and zeros
    mutated_mask[selected_ones] = 0
    mutated_mask[selected_zeros] = 1

    return mutated_mask

def crossover_mask(mask1, mask2):

    crossover_point = random.randint(1, len(mask1) - 1)

    # Combine initial segments up to the crossover point
    new_mask = np.concatenate([mask1[:crossover_point], mask2[crossover_point:]])

    # Count zeros and ones in the new mask and the parents
    num_zeros = np.sum(mask1 == 0)  # assuming mask1 and mask2 have the same number of zeros
    current_zeros = np.sum(new_mask == 0)

    # Balance zeros and ones if required
    if current_zeros != num_zeros:
        if current_zeros > num_zeros:
            # Too many zeros, replace some with ones
            zero_indices = np.where(new_mask[crossover_point:] == 0)[0] + crossover_point
            ones_to_flip = zero_indices[:current_zeros - num_zeros]
            new_mask[ones_to_flip] = 1
        else:
            # Too few zeros, replace some ones with zeros
            one_indices = np.where(new_mask[crossover_point:] == 1)[0] + crossover_point
            zeros_to_flip = one_indices[:(num_zeros - current_zeros)]
            new_mask[zeros_to_flip] = 0

    return new_mask

def evolutionary_optimization(model, initial_weights, train_loader, test_loader, criterion, num_batches=1, num_epochs=100, num_subnets=10, target_params=0, n=5, m=5, crossover_rate=0.5, print_accuraies = True):
    mask_pop = initialize_masks(initial_weights, target_params, num_subnets=num_subnets)
    top_accuracies = []
    top_losses = []

    test_epochs = [0]
    test_accuracies = []

    mask_pop, accuracies, losses = sort_and_evaluate_masks(mask_pop, model, initial_weights, test_loader, criterion, num_batches)
    test_accuracies.append(accuracies[0])


    for epoch in range(num_epochs):
        mask_pop, accuracies, losses = sort_and_evaluate_masks(mask_pop, model, initial_weights, train_loader, criterion, num_batches)
        top_loss = losses[0]
        top_accuracy = accuracies[0]
        top_accuracies.append(top_accuracy)
        top_losses.append(top_loss)

        #print accuracy
        if print_accuraies:
            print(f"Epoch {epoch + 1}/{num_epochs}: Lowest Loss = {top_loss:.8f}, Accuracy = {top_accuracy:.2f}")

        #terminate + elitism
        mask_pop = mask_pop[:n]

        new_masks = []

        for i in range(num_subnets-n):
            parent1 = mask_pop[random.randint(0, n-1)]
            parent2 = mask_pop[random.randint(0, n-1)]
            if random.random() < crossover_rate:  # crossover_rate is a hyperparameter
                new_mask = crossover_mask(parent1, parent2)
            else:
                new_mask = mutate_mask(parent1, m)  # or mutate_mask(parent2, m)
            new_masks.append(new_mask)

        mask_pop = mask_pop + new_masks

        assert len(mask_pop) == num_subnets

        if (epoch+1) % (num_epochs//10) == 0:
            mask_pop, accuracies, losses = sort_and_evaluate_masks(mask_pop, model, initial_weights, test_loader, criterion, num_batches)
            top_accuracy_test = accuracies[0]
            top_loss_test = losses[0]
            print(f"TEST RESULTS: Epoch {epoch + 1}/{num_epochs}: Lowest Loss = {top_loss_test:.8f}, Accuracy = {top_accuracy_test:.2f}")

            test_epochs.append(epoch+1)
            test_accuracies.append(top_accuracy_test)

    return test_epochs, test_accuracies

# %% [markdown]
# Data Loader

# %%
batch_size_train = 5000
batch_size_test = 10000

train_dataset = datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size_train, shuffle=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor(), download=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size_test, shuffle=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 256885978.83it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 30799820.45it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 216141869.44it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 3551552.72it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %% [markdown]
# Learning Curve

# %%
import time

# Check if GPU is available and set the device accordingly
device = torch.device("cpu")
print(f"Using {device} device")

# List of widths to iterate over
widths = [128, 256, 512] #1024?

# Initialize parameters
target_params = calc_params(128, 2)
print(target_params)
criterion = nn.CrossEntropyLoss()
num_batches = 1
num_epochs = 500
num_subnets = 10
n = 2  # number to keep
m = 1000  # number of mutations to mask
crossover_rate = 0
num_iter = 10

# Initialize a dictionary to store the accuracies for each width
all_accuracies_dict = {}

for width in widths:
    # Initialize a list to store the accuracies from all iterations for this width
    all_accuracies = []

    # Print model parameters
    print("Width =", width, "--", calc_params(width, 4), "params --", target_params / calc_params(width, 4), "% mask")

    for i in range(num_iter):

        # Initialize Model
        model = MLP(28 * 28, width, 10, 3).to(device)

        # Save a copy of the initial weights to list of numpy arrays
        initial_weights = [layer.weight.detach().cpu().clone().numpy() for layer in model.layers]

        # Start timing
        start_time = time.time()

        # Perform the evolutionary optimization
        test_epochs, test_accuracies  = evolutionary_optimization(model, initial_weights, train_loader, test_loader, criterion, num_batches, num_epochs, num_subnets, target_params, n, m, crossover_rate, print_accuraies=True)

        # End timing
        end_time = time.time()
        print(f"Width {width}, Iteration {i+1}: {end_time - start_time:.2f} seconds")

        # Store the accuracies
        all_accuracies.append(test_accuracies)

    # Convert the list of accuracies to a numpy array and store in the dictionary
    all_accuracies_dict[width] = np.array(all_accuracies)

    plt.figure(figsize=(10, 6))

    ax1 = plt.gca()  # Get current axes for plotting accuracies

    for width, all_accuracies in all_accuracies_dict.items():
        # Calculate the average and standard deviation across iterations for each epoch
        avg_accuracies = np.mean(all_accuracies, axis=0)
        std_dev_accuracies = np.std(all_accuracies, axis=0)

        # Plot accuracies for each width on the primary y-axis
        ax1.plot(test_epochs, avg_accuracies, label=f'Width {width} Average Accuracy')
        ax1.fill_between(test_epochs, avg_accuracies - std_dev_accuracies, avg_accuracies + std_dev_accuracies, alpha=0.2)

    # Labels for the primary y-axis
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.tick_params(axis='y')

    # Titles and grids
    plt.title('Evolutionary Accuracies and Losses vs Epochs')
    ax1.legend(loc='upper left')
    ax1.grid(True)

    plt.show()

plt.figure(figsize=(10, 6))

ax1 = plt.gca()  # Get current axes for plotting accuracies

for width, all_accuracies in all_accuracies_dict.items():
    # Calculate the average and standard deviation across iterations for each epoch
    avg_accuracies = np.mean(all_accuracies, axis=0)
    std_dev_accuracies = np.std(all_accuracies, axis=0)

    # Plot accuracies with error bars for each width on the primary y-axis
    ax1.errorbar(test_epochs, avg_accuracies, yerr=std_dev_accuracies, label=f'Width {width} Average Accuracy', fmt='-o', capsize=5)

# Labels for the primary y-axis
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.tick_params(axis='y')

# Titles and grids
plt.title('Evolutionary Accuracies vs Epochs')
ax1.legend(loc='upper left')
ax1.grid(True)

plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 109/500: Lowest Loss = 0.00045991, Accuracy = 28.86
# Epoch 110/500: Lowest Loss = 0.00045999, Accuracy = 28.28
# Epoch 111/500: Lowest Loss = 0.00045995, Accuracy = 29.36
# Epoch 112/500: Lowest Loss = 0.00046000, Accuracy = 28.98
# Epoch 113/500: Lowest Loss = 0.00046003, Accuracy = 28.88
# Epoch 114/500: Lowest Loss = 0.00045999, Accuracy = 29.20
# Epoch 115/500: Lowest Loss = 0.00046001, Accuracy = 29.20
# Epoch 116/500: Lowest Loss = 0.00045999, Accuracy = 28.98
# Epoch 117/500: Lowest Loss = 0.00045998, Accuracy = 28.74
# Epoch 118/500: Lowest Loss = 0.00046002, Accuracy = 28.14
# Epoch 119/500: Lowest Loss = 0.00045999, Accuracy = 29.08
# Epoch 120/500: Lowest Loss = 0.00046001, Accuracy = 28.44
# Epoch 121/500: Lowest Loss = 0.00046000, Accuracy = 29.14
# Epoch 122/500: Lowest Loss = 0.00045998, Accuracy = 29.96
# Epoch 123/500: Lowest Loss = 0.00045999, Accuracy = 29.18
# Epoch 124/500: Lowest Loss = 0.00045995, Accuracy = 28.88
# Epoch 125/500: Lowest Loss = 0.00045999, Accuracy = 28.48
# Epoch 126/500: Lowest Loss = 0.00046002, Accuracy = 28.62
# Epoch 127/500: Lowest Loss = 0.00046000, Accuracy = 28.90
# Epoch 128/500: Lowest Loss = 0.00045998, Accuracy = 30.06
# Epoch 129/500: Lowest Loss = 0.00046001, Accuracy = 29.38
# Epoch 130/500: Lowest Loss = 0.00045998, Accuracy = 29.32
# Epoch 131/500: Lowest Loss = 0.00045996, Accuracy = 29.30
# Epoch 132/500: Lowest Loss = 0.00046000, Accuracy = 28.34
# Epoch 133/500: Lowest Loss = 0.00046001, Accuracy = 29.14
# Epoch 134/500: Lowest Loss = 0.00045992, Accuracy = 30.40
# Epoch 135/500: Lowest Loss = 0.00045993, Accuracy = 29.48
# Epoch 136/500: Lowest Loss = 0.00045989, Accuracy = 31.18
# Epoch 137/500: Lowest Loss = 0.00045994, Accuracy = 30.32
# Epoch 138/500: Lowest Loss = 0.00045995, Accuracy = 30.58
# Epoch 139/500: Lowest Loss = 0.00045989, Accuracy = 31.20
# Epoch 140/500: Lowest Loss = 0.00045990, Accuracy = 31.58
# Epoch 141/500: Lowest Loss = 0.00045989, Accuracy = 31.40
# Epoch 142/500: Lowest Loss = 0.00045988, Accuracy = 32.04
# Epoch 143/500: Lowest Loss = 0.00045992, Accuracy = 30.50
# Epoch 144/500: Lowest Loss = 0.00045990, Accuracy = 30.64
# Epoch 145/500: Lowest Loss = 0.00045991, Accuracy = 30.82
# Epoch 146/500: Lowest Loss = 0.00045989, Accuracy = 30.92
# Epoch 147/500: Lowest Loss = 0.00045991, Accuracy = 31.18
# Epoch 148/500: Lowest Loss = 0.00045988, Accuracy = 31.10
# Epoch 149/500: Lowest Loss = 0.00045986, Accuracy = 31.60
# Epoch 150/500: Lowest Loss = 0.00045991, Accuracy = 30.94
# TEST RESULTS: Epoch 150/500: Lowest Loss = 0.00022998, Accuracy = 30.90
# Epoch 151/500: Lowest Loss = 0.00045997, Accuracy = 31.22
# Epoch 152/500: Lowest Loss = 0.00045992, Accuracy = 30.54
# Epoch 153/500: Lowest Loss = 0.00045991, Accuracy = 31.30
# Epoch 154/500: Lowest Loss = 0.00045995, Accuracy = 30.36
# Epoch 155/500: Lowest Loss = 0.00045998, Accuracy = 29.64
# Epoch 156/500: Lowest Loss = 0.00045995, Accuracy = 30.00
# Epoch 157/500: Lowest Loss = 0.00045994, Accuracy = 29.98
# Epoch 158/500: Lowest Loss = 0.00045993, Accuracy = 30.68
# Epoch 159/500: Lowest Loss = 0.00045995, Accuracy = 29.56
# Epoch 160/500: Lowest Loss = 0.00045997, Accuracy = 30.28
# Epoch 161/500: Lowest Loss = 0.00045998, Accuracy = 29.40
# Epoch 162/500: Lowest Loss = 0.00045996, Accuracy = 30.58
# Epoch 163/500: Lowest Loss = 0.00046000, Accuracy = 29.52
# Epoch 164/500: Lowest Loss = 0.00045997, Accuracy = 30.06
# Epoch 165/500: Lowest Loss = 0.00045996, Accuracy = 29.46
# Epoch 166/500: Lowest Loss = 0.00046000, Accuracy = 29.06
# Epoch 167/500: Lowest Loss = 0.00045998, Accuracy = 28.96
# Epoch 168/500: Lowest Loss = 0.00045997, Accuracy = 29.30
# Epoch 169/500: Lowest Loss = 0.00045994, Accuracy = 29.90
# Epoch 170/500: Lowest Loss = 0.00045992, Accuracy = 31.30
# Epoch 171/500: Lowest Loss = 0.00045996, Accuracy = 30.56
# Epoch 172/500: Lowest Loss = 0.00046001, Accuracy = 30.08
# Epoch 173/500: Lowest Loss = 0.00046000, Accuracy = 31.20
# Epoch 174/500: Lowest Loss = 0.00045998, Accuracy = 30.10
# Epoch 175/500: Lowest Loss = 0.00045998, Accuracy = 30.06
# Epoch 176/500: Lowest Loss = 0.00045994, Accuracy = 28.72
# Epoch 177/500: Lowest Loss = 0.00045999, Accuracy = 28.88
# Epoch 178/500: Lowest Loss = 0.00046003, Accuracy = 28.90
# Epoch 179/500: Lowest Loss = 0.00046000, Accuracy = 28.54
# Epoch 180/500: Lowest Loss = 0.00045999, Accuracy = 29.30
# Epoch 181/500: Lowest Loss = 0.00045998, Accuracy = 29.40
# Epoch 182/500: Lowest Loss = 0.00046000, Accuracy = 29.18
# Epoch 183/500: Lowest Loss = 0.00046001, Accuracy = 29.30
# Epoch 184/500: Lowest Loss = 0.00045999, Accuracy = 28.50
# Epoch 185/500: Lowest Loss = 0.00045999, Accuracy = 28.86
# Epoch 186/500: Lowest Loss = 0.00045999, Accuracy = 28.80
# Epoch 187/500: Lowest Loss = 0.00046001, Accuracy = 28.52
# Epoch 188/500: Lowest Loss = 0.00045995, Accuracy = 29.80
# Epoch 189/500: Lowest Loss = 0.00045991, Accuracy = 30.96
# Epoch 190/500: Lowest Loss = 0.00045997, Accuracy = 29.22
# Epoch 191/500: Lowest Loss = 0.00045989, Accuracy = 30.28
# Epoch 192/500: Lowest Loss = 0.00045997, Accuracy = 30.60
# Epoch 193/500: Lowest Loss = 0.00045989, Accuracy = 30.18
# Epoch 194/500: Lowest Loss = 0.00045997, Accuracy = 30.02
# Epoch 195/500: Lowest Loss = 0.00046000, Accuracy = 30.26
# Epoch 196/500: Lowest Loss = 0.00045993, Accuracy = 31.02
# Epoch 197/500: Lowest Loss = 0.00045996, Accuracy = 29.54
# Epoch 198/500: Lowest Loss = 0.00045996, Accuracy = 29.30
# Epoch 199/500: Lowest Loss = 0.00045995, Accuracy = 30.00
# Epoch 200/500: Lowest Loss = 0.00045999, Accuracy = 29.68
# TEST RESULTS: Epoch 200/500: Lowest Loss = 0.00023000, Accuracy = 29.98
# Epoch 201/500: Lowest Loss = 0.00045993, Accuracy = 30.72
# Epoch 202/500: Lowest Loss = 0.00045993, Accuracy = 30.22
# Epoch 203/500: Lowest Loss = 0.00045991, Accuracy = 30.92
# Epoch 204/500: Lowest Loss = 0.00045993, Accuracy = 30.06
# Epoch 205/500: Lowest Loss = 0.00045996, Accuracy = 29.70
# Epoch 206/500: Lowest Loss = 0.00045997, Accuracy = 29.86
# Epoch 207/500: Lowest Loss = 0.00045995, Accuracy = 29.98
# Epoch 208/500: Lowest Loss = 0.00045993, Accuracy = 30.50
# Epoch 209/500: Lowest Loss = 0.00045996, Accuracy = 30.82
# Epoch 210/500: Lowest Loss = 0.00045996, Accuracy = 30.54
# Epoch 211/500: Lowest Loss = 0.00045997, Accuracy = 29.80
# Epoch 212/500: Lowest Loss = 0.00045994, Accuracy = 29.64
# Epoch 213/500: Lowest Loss = 0.00045995, Accuracy = 29.94
# Epoch 214/500: Lowest Loss = 0.00045994, Accuracy = 30.18
# Epoch 215/500: Lowest Loss = 0.00045993, Accuracy = 30.34
# Epoch 216/500: Lowest Loss = 0.00045997, Accuracy = 31.38
# Epoch 217/500: Lowest Loss = 0.00045988, Accuracy = 32.82
# Epoch 218/500: Lowest Loss = 0.00045993, Accuracy = 30.80
# Epoch 219/500: Lowest Loss = 0.00045998, Accuracy = 30.50
# Epoch 220/500: Lowest Loss = 0.00045996, Accuracy = 31.34
# Epoch 221/500: Lowest Loss = 0.00045994, Accuracy = 32.10
# Epoch 222/500: Lowest Loss = 0.00045994, Accuracy = 31.50
# Epoch 223/500: Lowest Loss = 0.00045993, Accuracy = 32.66
# Epoch 224/500: Lowest Loss = 0.00045997, Accuracy = 30.98
# Epoch 225/500: Lowest Loss = 0.00045994, Accuracy = 31.72
# Epoch 226/500: Lowest Loss = 0.00045994, Accuracy = 31.66
# Epoch 227/500: Lowest Loss = 0.00045994, Accuracy = 32.06
# Epoch 228/500: Lowest Loss = 0.00045991, Accuracy = 33.26
# Epoch 229/500: Lowest Loss = 0.00045994, Accuracy = 31.28
# Epoch 230/500: Lowest Loss = 0.00045997, Accuracy = 31.84
# Epoch 231/500: Lowest Loss = 0.00045994, Accuracy = 32.32
# Epoch 232/500: Lowest Loss = 0.00045992, Accuracy = 32.70
# Epoch 233/500: Lowest Loss = 0.00045995, Accuracy = 32.90
# Epoch 234/500: Lowest Loss = 0.00045994, Accuracy = 31.58
# Epoch 235/500: Lowest Loss = 0.00045996, Accuracy = 31.36
# Epoch 236/500: Lowest Loss = 0.00045989, Accuracy = 32.64
# Epoch 237/500: Lowest Loss = 0.00045991, Accuracy = 32.12
# Epoch 238/500: Lowest Loss = 0.00045987, Accuracy = 32.30
# Epoch 239/500: Lowest Loss = 0.00045992, Accuracy = 31.60
# Epoch 240/500: Lowest Loss = 0.00045990, Accuracy = 31.68
# Epoch 241/500: Lowest Loss = 0.00045999, Accuracy = 31.58
# Epoch 242/500: Lowest Loss = 0.00045996, Accuracy = 32.44
# Epoch 243/500: Lowest Loss = 0.00045989, Accuracy = 32.72
# Epoch 244/500: Lowest Loss = 0.00045991, Accuracy = 32.54
# Epoch 245/500: Lowest Loss = 0.00045987, Accuracy = 32.20
# Epoch 246/500: Lowest Loss = 0.00045990, Accuracy = 31.98
# Epoch 247/500: Lowest Loss = 0.00045992, Accuracy = 31.30
# Epoch 248/500: Lowest Loss = 0.00045994, Accuracy = 31.10
# Epoch 249/500: Lowest Loss = 0.00045991, Accuracy = 31.90
# Epoch 250/500: Lowest Loss = 0.00045991, Accuracy = 31.92
# TEST RESULTS: Epoch 250/500: Lowest Loss = 0.00022992, Accuracy = 32.19
# Epoch 251/500: Lowest Loss = 0.00045987, Accuracy = 32.24
# Epoch 252/500: Lowest Loss = 0.00045990, Accuracy = 32.16
# Epoch 253/500: Lowest Loss = 0.00045986, Accuracy = 32.16
# Epoch 254/500: Lowest Loss = 0.00045985, Accuracy = 32.28
# Epoch 255/500: Lowest Loss = 0.00045990, Accuracy = 31.22
# Epoch 256/500: Lowest Loss = 0.00045995, Accuracy = 30.72
# Epoch 257/500: Lowest Loss = 0.00045988, Accuracy = 32.20
# Epoch 258/500: Lowest Loss = 0.00045990, Accuracy = 31.54
# Epoch 259/500: Lowest Loss = 0.00045992, Accuracy = 31.72
# Epoch 260/500: Lowest Loss = 0.00045991, Accuracy = 31.60
# Epoch 261/500: Lowest Loss = 0.00045993, Accuracy = 30.70
# Epoch 262/500: Lowest Loss = 0.00045994, Accuracy = 32.36
# Epoch 263/500: Lowest Loss = 0.00045986, Accuracy = 32.62
# Epoch 264/500: Lowest Loss = 0.00045991, Accuracy = 31.76
# Epoch 265/500: Lowest Loss = 0.00045994, Accuracy = 31.82
# Epoch 266/500: Lowest Loss = 0.00045993, Accuracy = 31.08
# Epoch 267/500: Lowest Loss = 0.00045989, Accuracy = 31.74
# Epoch 268/500: Lowest Loss = 0.00045991, Accuracy = 31.46
# Epoch 269/500: Lowest Loss = 0.00045993, Accuracy = 31.52
# Epoch 270/500: Lowest Loss = 0.00045993, Accuracy = 31.36
# Epoch 271/500: Lowest Loss = 0.00045995, Accuracy = 31.28
# Epoch 272/500: Lowest Loss = 0.00045989, Accuracy = 31.74
# Epoch 273/500: Lowest Loss = 0.00045993, Accuracy = 30.96
# Epoch 274/500: Lowest Loss = 0.00045983, Accuracy = 31.56
# Epoch 275/500: Lowest Loss = 0.00045989, Accuracy = 31.82
# Epoch 276/500: Lowest Loss = 0.00045992, Accuracy = 30.04
# Epoch 277/500: Lowest Loss = 0.00045987, Accuracy = 31.84
# Epoch 278/500: Lowest Loss = 0.00045986, Accuracy = 32.14
# Epoch 279/500: Lowest Loss = 0.00045990, Accuracy = 31.76
# Epoch 280/500: Lowest Loss = 0.00045990, Accuracy = 32.40
# Epoch 281/500: Lowest Loss = 0.00045991, Accuracy = 30.54
# Epoch 282/500: Lowest Loss = 0.00045992, Accuracy = 30.38
# Epoch 283/500: Lowest Loss = 0.00045990, Accuracy = 31.04
# Epoch 284/500: Lowest Loss = 0.00045990, Accuracy = 31.24
# Epoch 285/500: Lowest Loss = 0.00045987, Accuracy = 31.88
# Epoch 286/500: Lowest Loss = 0.00045991, Accuracy = 30.30
# Epoch 287/500: Lowest Loss = 0.00045990, Accuracy = 31.24
# Epoch 288/500: Lowest Loss = 0.00045987, Accuracy = 31.74
# Epoch 289/500: Lowest Loss = 0.00045992, Accuracy = 30.18
# Epoch 290/500: Lowest Loss = 0.00045990, Accuracy = 29.68
# Epoch 291/500: Lowest Loss = 0.00045991, Accuracy = 30.38
# Epoch 292/500: Lowest Loss = 0.00045992, Accuracy = 30.88
# Epoch 293/500: Lowest Loss = 0.00045988, Accuracy = 31.60
# Epoch 294/500: Lowest Loss = 0.00045991, Accuracy = 31.38
# Epoch 295/500: Lowest Loss = 0.00045985, Accuracy = 33.16
# Epoch 296/500: Lowest Loss = 0.00045988, Accuracy = 32.18
# Epoch 297/500: Lowest Loss = 0.00045986, Accuracy = 32.18
# Epoch 298/500: Lowest Loss = 0.00045987, Accuracy = 32.12
# Epoch 299/500: Lowest Loss = 0.00045986, Accuracy = 32.66
# Epoch 300/500: Lowest Loss = 0.00045983, Accuracy = 33.18
# TEST RESULTS: Epoch 300/500: Lowest Loss = 0.00022992, Accuracy = 32.38
# Epoch 301/500: Lowest Loss = 0.00045987, Accuracy = 32.18
# Epoch 302/500: Lowest Loss = 0.00045988, Accuracy = 33.02
# Epoch 303/500: Lowest Loss = 0.00045990, Accuracy = 32.30
# Epoch 304/500: Lowest Loss = 0.00045987, Accuracy = 33.04
# Epoch 305/500: Lowest Loss = 0.00045987, Accuracy = 32.66
# Epoch 306/500: Lowest Loss = 0.00045986, Accuracy = 33.14
# Epoch 307/500: Lowest Loss = 0.00045988, Accuracy = 33.18
# Epoch 308/500: Lowest Loss = 0.00045988, Accuracy = 33.40
# Epoch 309/500: Lowest Loss = 0.00045985, Accuracy = 33.20
# Epoch 310/500: Lowest Loss = 0.00045982, Accuracy = 33.86
# Epoch 311/500: Lowest Loss = 0.00045988, Accuracy = 33.60
# Epoch 312/500: Lowest Loss = 0.00045989, Accuracy = 33.02
# Epoch 313/500: Lowest Loss = 0.00045988, Accuracy = 32.42
# Epoch 314/500: Lowest Loss = 0.00045988, Accuracy = 32.52
# Epoch 315/500: Lowest Loss = 0.00045986, Accuracy = 31.56
# Epoch 316/500: Lowest Loss = 0.00045985, Accuracy = 33.28
# Epoch 317/500: Lowest Loss = 0.00045986, Accuracy = 34.40
# Epoch 318/500: Lowest Loss = 0.00045991, Accuracy = 33.62
# Epoch 319/500: Lowest Loss = 0.00045989, Accuracy = 33.30
# Epoch 320/500: Lowest Loss = 0.00045986, Accuracy = 32.50
# Epoch 321/500: Lowest Loss = 0.00045991, Accuracy = 32.42
# Epoch 322/500: Lowest Loss = 0.00045990, Accuracy = 33.28
# Epoch 323/500: Lowest Loss = 0.00045990, Accuracy = 33.24
# Epoch 324/500: Lowest Loss = 0.00045989, Accuracy = 32.88
# Epoch 325/500: Lowest Loss = 0.00045995, Accuracy = 32.10
# Epoch 326/500: Lowest Loss = 0.00045991, Accuracy = 33.18
# Epoch 327/500: Lowest Loss = 0.00045990, Accuracy = 33.60
# Epoch 328/500: Lowest Loss = 0.00045989, Accuracy = 32.86
# Epoch 329/500: Lowest Loss = 0.00045989, Accuracy = 32.50
# Epoch 330/500: Lowest Loss = 0.00045989, Accuracy = 34.02
# Epoch 331/500: Lowest Loss = 0.00045990, Accuracy = 33.28
# Epoch 332/500: Lowest Loss = 0.00045989, Accuracy = 32.92
# Epoch 333/500: Lowest Loss = 0.00045988, Accuracy = 33.06
# Epoch 334/500: Lowest Loss = 0.00045991, Accuracy = 32.92
# Epoch 335/500: Lowest Loss = 0.00045986, Accuracy = 34.00
# Epoch 336/500: Lowest Loss = 0.00045985, Accuracy = 33.24
# Epoch 337/500: Lowest Loss = 0.00045987, Accuracy = 32.96
# Epoch 338/500: Lowest Loss = 0.00045985, Accuracy = 33.36
# Epoch 339/500: Lowest Loss = 0.00045983, Accuracy = 33.92
# Epoch 340/500: Lowest Loss = 0.00045987, Accuracy = 32.84
# Epoch 341/500: Lowest Loss = 0.00045984, Accuracy = 34.38
# Epoch 342/500: Lowest Loss = 0.00045979, Accuracy = 34.24
# Epoch 343/500: Lowest Loss = 0.00045984, Accuracy = 34.50
# Epoch 344/500: Lowest Loss = 0.00045986, Accuracy = 34.00
# Epoch 345/500: Lowest Loss = 0.00045982, Accuracy = 34.16
# Epoch 346/500: Lowest Loss = 0.00045983, Accuracy = 33.76
# Epoch 347/500: Lowest Loss = 0.00045986, Accuracy = 33.84
# Epoch 348/500: Lowest Loss = 0.00045982, Accuracy = 34.12
# Epoch 349/500: Lowest Loss = 0.00045985, Accuracy = 33.52
# Epoch 350/500: Lowest Loss = 0.00045980, Accuracy = 35.70
# TEST RESULTS: Epoch 350/500: Lowest Loss = 0.00022991, Accuracy = 35.01
# Epoch 351/500: Lowest Loss = 0.00045987, Accuracy = 33.58
# Epoch 352/500: Lowest Loss = 0.00045980, Accuracy = 35.24
# Epoch 353/500: Lowest Loss = 0.00045987, Accuracy = 34.32
# Epoch 354/500: Lowest Loss = 0.00045986, Accuracy = 33.88
# Epoch 355/500: Lowest Loss = 0.00045987, Accuracy = 34.34
# Epoch 356/500: Lowest Loss = 0.00045989, Accuracy = 33.42
# Epoch 357/500: Lowest Loss = 0.00045981, Accuracy = 33.80
# Epoch 358/500: Lowest Loss = 0.00045987, Accuracy = 33.44
# Epoch 359/500: Lowest Loss = 0.00045986, Accuracy = 33.82
# Epoch 360/500: Lowest Loss = 0.00045985, Accuracy = 33.48
# Epoch 361/500: Lowest Loss = 0.00045985, Accuracy = 33.98
# Epoch 362/500: Lowest Loss = 0.00045987, Accuracy = 34.28
# Epoch 363/500: Lowest Loss = 0.00045988, Accuracy = 33.32
# Epoch 364/500: Lowest Loss = 0.00045990, Accuracy = 33.22
# Epoch 365/500: Lowest Loss = 0.00045991, Accuracy = 35.24
# Epoch 366/500: Lowest Loss = 0.00045990, Accuracy = 33.64
# Epoch 367/500: Lowest Loss = 0.00045992, Accuracy = 34.34
# Epoch 368/500: Lowest Loss = 0.00045990, Accuracy = 34.60
# Epoch 369/500: Lowest Loss = 0.00045993, Accuracy = 34.14
# Epoch 370/500: Lowest Loss = 0.00045988, Accuracy = 34.02
# Epoch 371/500: Lowest Loss = 0.00045991, Accuracy = 33.92
# Epoch 372/500: Lowest Loss = 0.00045990, Accuracy = 34.08
# Epoch 373/500: Lowest Loss = 0.00045989, Accuracy = 34.04
# Epoch 374/500: Lowest Loss = 0.00045991, Accuracy = 34.66
# Epoch 375/500: Lowest Loss = 0.00045994, Accuracy = 34.62
# Epoch 376/500: Lowest Loss = 0.00045992, Accuracy = 33.50
# Epoch 377/500: Lowest Loss = 0.00045989, Accuracy = 34.26
# Epoch 378/500: Lowest Loss = 0.00045991, Accuracy = 33.48
# Epoch 379/500: Lowest Loss = 0.00045990, Accuracy = 34.80
# Epoch 380/500: Lowest Loss = 0.00045991, Accuracy = 33.38
# Epoch 381/500: Lowest Loss = 0.00045993, Accuracy = 32.92
# Epoch 382/500: Lowest Loss = 0.00045991, Accuracy = 35.04
# Epoch 383/500: Lowest Loss = 0.00045991, Accuracy = 33.72
# Epoch 384/500: Lowest Loss = 0.00045992, Accuracy = 34.14
# Epoch 385/500: Lowest Loss = 0.00045992, Accuracy = 33.88
# Epoch 386/500: Lowest Loss = 0.00045989, Accuracy = 34.36
# Epoch 387/500: Lowest Loss = 0.00045990, Accuracy = 34.64
# Epoch 388/500: Lowest Loss = 0.00045992, Accuracy = 34.96
# Epoch 389/500: Lowest Loss = 0.00045989, Accuracy = 34.20
# Epoch 390/500: Lowest Loss = 0.00045986, Accuracy = 35.38
# Epoch 391/500: Lowest Loss = 0.00045991, Accuracy = 34.80
# Epoch 392/500: Lowest Loss = 0.00045989, Accuracy = 35.14
# Epoch 393/500: Lowest Loss = 0.00045992, Accuracy = 34.46
# Epoch 394/500: Lowest Loss = 0.00045994, Accuracy = 34.10
# Epoch 395/500: Lowest Loss = 0.00045993, Accuracy = 33.68
# Epoch 396/500: Lowest Loss = 0.00045995, Accuracy = 33.92
# Epoch 397/500: Lowest Loss = 0.00045990, Accuracy = 34.50
# Epoch 398/500: Lowest Loss = 0.00045991, Accuracy = 35.20
# Epoch 399/500: Lowest Loss = 0.00045989, Accuracy = 36.00
# Epoch 400/500: Lowest Loss = 0.00045989, Accuracy = 36.08
# TEST RESULTS: Epoch 400/500: Lowest Loss = 0.00022995, Accuracy = 35.46
# Epoch 401/500: Lowest Loss = 0.00045995, Accuracy = 34.98
# Epoch 402/500: Lowest Loss = 0.00045988, Accuracy = 35.98
# Epoch 403/500: Lowest Loss = 0.00045996, Accuracy = 34.48
# Epoch 404/500: Lowest Loss = 0.00045992, Accuracy = 35.42
# Epoch 405/500: Lowest Loss = 0.00045993, Accuracy = 33.98
# Epoch 406/500: Lowest Loss = 0.00045990, Accuracy = 35.76
# Epoch 407/500: Lowest Loss = 0.00045989, Accuracy = 35.34
# Epoch 408/500: Lowest Loss = 0.00045991, Accuracy = 35.60
# Epoch 409/500: Lowest Loss = 0.00045990, Accuracy = 35.32
# Epoch 410/500: Lowest Loss = 0.00045991, Accuracy = 35.22
# Epoch 411/500: Lowest Loss = 0.00045986, Accuracy = 36.58
# Epoch 412/500: Lowest Loss = 0.00045989, Accuracy = 36.22
# Epoch 413/500: Lowest Loss = 0.00045990, Accuracy = 34.16
# Epoch 414/500: Lowest Loss = 0.00045988, Accuracy = 36.08
# Epoch 415/500: Lowest Loss = 0.00045988, Accuracy = 36.28
# Epoch 416/500: Lowest Loss = 0.00045992, Accuracy = 34.92
# Epoch 417/500: Lowest Loss = 0.00045992, Accuracy = 34.30
# Epoch 418/500: Lowest Loss = 0.00045990, Accuracy = 35.24
# Epoch 419/500: Lowest Loss = 0.00045990, Accuracy = 35.66
# Epoch 420/500: Lowest Loss = 0.00045990, Accuracy = 35.92
# Epoch 421/500: Lowest Loss = 0.00045991, Accuracy = 34.68
# Epoch 422/500: Lowest Loss = 0.00045989, Accuracy = 36.28
# Epoch 423/500: Lowest Loss = 0.00045990, Accuracy = 34.74
# Epoch 424/500: Lowest Loss = 0.00045990, Accuracy = 34.92
# Epoch 425/500: Lowest Loss = 0.00045991, Accuracy = 35.96
# Epoch 426/500: Lowest Loss = 0.00045993, Accuracy = 35.22
# Epoch 427/500: Lowest Loss = 0.00045987, Accuracy = 35.84
# Epoch 428/500: Lowest Loss = 0.00045991, Accuracy = 35.02
# Epoch 429/500: Lowest Loss = 0.00045990, Accuracy = 35.60
# Epoch 430/500: Lowest Loss = 0.00045991, Accuracy = 35.58
# Epoch 431/500: Lowest Loss = 0.00045993, Accuracy = 35.48
# Epoch 432/500: Lowest Loss = 0.00045986, Accuracy = 35.56
# Epoch 433/500: Lowest Loss = 0.00045989, Accuracy = 35.70
# Epoch 434/500: Lowest Loss = 0.00045992, Accuracy = 34.78
# Epoch 435/500: Lowest Loss = 0.00045992, Accuracy = 34.26
# Epoch 436/500: Lowest Loss = 0.00045988, Accuracy = 35.24
# Epoch 437/500: Lowest Loss = 0.00045988, Accuracy = 34.64
# Epoch 438/500: Lowest Loss = 0.00045990, Accuracy = 36.02
# Epoch 439/500: Lowest Loss = 0.00045990, Accuracy = 35.08
# Epoch 440/500: Lowest Loss = 0.00045988, Accuracy = 35.96
# Epoch 441/500: Lowest Loss = 0.00045987, Accuracy = 34.98
# Epoch 442/500: Lowest Loss = 0.00045991, Accuracy = 34.22
# Epoch 443/500: Lowest Loss = 0.00045989, Accuracy = 34.96
# Epoch 444/500: Lowest Loss = 0.00045990, Accuracy = 34.92
# Epoch 445/500: Lowest Loss = 0.00045986, Accuracy = 34.72
# Epoch 446/500: Lowest Loss = 0.00045992, Accuracy = 33.74
# Epoch 447/500: Lowest Loss = 0.00045988, Accuracy = 34.60
# Epoch 448/500: Lowest Loss = 0.00045989, Accuracy = 34.74
# Epoch 449/500: Lowest Loss = 0.00045988, Accuracy = 34.66
# Epoch 450/500: Lowest Loss = 0.00045987, Accuracy = 34.58
# TEST RESULTS: Epoch 450/500: Lowest Loss = 0.00022993, Accuracy = 35.21
# Epoch 451/500: Lowest Loss = 0.00045986, Accuracy = 34.32
# Epoch 452/500: Lowest Loss = 0.00045991, Accuracy = 34.46
# Epoch 453/500: Lowest Loss = 0.00045990, Accuracy = 33.82
# Epoch 454/500: Lowest Loss = 0.00045989, Accuracy = 34.56
# Epoch 455/500: Lowest Loss = 0.00045991, Accuracy = 34.28
# Epoch 456/500: Lowest Loss = 0.00045993, Accuracy = 34.42
# Epoch 457/500: Lowest Loss = 0.00045992, Accuracy = 33.60
# Epoch 458/500: Lowest Loss = 0.00045990, Accuracy = 34.22
# Epoch 459/500: Lowest Loss = 0.00045991, Accuracy = 34.82
# Epoch 460/500: Lowest Loss = 0.00045988, Accuracy = 34.38
# Epoch 461/500: Lowest Loss = 0.00045989, Accuracy = 34.12
# Epoch 462/500: Lowest Loss = 0.00045990, Accuracy = 33.60
# Epoch 463/500: Lowest Loss = 0.00045990, Accuracy = 35.12
# Epoch 464/500: Lowest Loss = 0.00045988, Accuracy = 34.98
# Epoch 465/500: Lowest Loss = 0.00045991, Accuracy = 33.40
# Epoch 466/500: Lowest Loss = 0.00045988, Accuracy = 34.36
# Epoch 467/500: Lowest Loss = 0.00045989, Accuracy = 33.40
# Epoch 468/500: Lowest Loss = 0.00045991, Accuracy = 33.34
# Epoch 469/500: Lowest Loss = 0.00045992, Accuracy = 33.02
# Epoch 470/500: Lowest Loss = 0.00045989, Accuracy = 34.02
# Epoch 471/500: Lowest Loss = 0.00045987, Accuracy = 33.72
# Epoch 472/500: Lowest Loss = 0.00045991, Accuracy = 33.96
# Epoch 473/500: Lowest Loss = 0.00045993, Accuracy = 33.20
# Epoch 474/500: Lowest Loss = 0.00045988, Accuracy = 33.96
# Epoch 475/500: Lowest Loss = 0.00045990, Accuracy = 33.58
# Epoch 476/500: Lowest Loss = 0.00045991, Accuracy = 34.48
# Epoch 477/500: Lowest Loss = 0.00045988, Accuracy = 34.86
# Epoch 478/500: Lowest Loss = 0.00045990, Accuracy = 33.26
# Epoch 479/500: Lowest Loss = 0.00045992, Accuracy = 33.06
# Epoch 480/500: Lowest Loss = 0.00045995, Accuracy = 32.38
# Epoch 481/500: Lowest Loss = 0.00045989, Accuracy = 33.22
# Epoch 482/500: Lowest Loss = 0.00045992, Accuracy = 33.60
# Epoch 483/500: Lowest Loss = 0.00045990, Accuracy = 32.88
# Epoch 484/500: Lowest Loss = 0.00045991, Accuracy = 33.30
# Epoch 485/500: Lowest Loss = 0.00045988, Accuracy = 34.16
# Epoch 486/500: Lowest Loss = 0.00045986, Accuracy = 34.22
# Epoch 487/500: Lowest Loss = 0.00045989, Accuracy = 32.88
# Epoch 488/500: Lowest Loss = 0.00045988, Accuracy = 33.40
# Epoch 489/500: Lowest Loss = 0.00045987, Accuracy = 33.14
# Epoch 490/500: Lowest Loss = 0.00045990, Accuracy = 32.78
# Epoch 491/500: Lowest Loss = 0.00045989, Accuracy = 33.84
# Epoch 492/500: Lowest Loss = 0.00045991, Accuracy = 33.72
# Epoch 493/500: Lowest Loss = 0.00045987, Accuracy = 33.14
# Epoch 494/500: Lowest Loss = 0.00045989, Accuracy = 34.58
# Epoch 495/500: Lowest Loss = 0.00045988, Accuracy = 34.16
# Epoch 496/500: Lowest Loss = 0.00045987, Accuracy = 34.18
# Epoch 497/500: Lowest Loss = 0.00045986, Accuracy = 35.36
# Epoch 498/500: Lowest Loss = 0.00045988, Accuracy = 33.64
# Epoch 499/500: Lowest Loss = 0.00045990, Accuracy = 33.02
# Epoch 500/500: Lowest Loss = 0.00045989, Accuracy = 33.50
# TEST RESULTS: Epoch 500/500: Lowest Loss = 0.00022993, Accuracy = 35.11
# Width 128, Iteration 1: 2472.40 seconds
# Epoch 1/500: Lowest Loss = 0.00046049, Accuracy = 13.46
# Epoch 2/500: Lowest Loss = 0.00046048, Accuracy = 13.72
# Epoch 3/500: Lowest Loss = 0.00046044, Accuracy = 15.28
# Epoch 4/500: Lowest Loss = 0.00046042, Accuracy = 16.24
# Epoch 5/500: Lowest Loss = 0.00046046, Accuracy = 16.14
# Epoch 6/500: Lowest Loss = 0.00046037, Accuracy = 18.38
# Epoch 7/500: Lowest Loss = 0.00046042, Accuracy = 19.18
# Epoch 8/500: Lowest Loss = 0.00046028, Accuracy = 21.52
# Epoch 9/500: Lowest Loss = 0.00046029, Accuracy = 20.82
# Epoch 10/500: Lowest Loss = 0.00046030, Accuracy = 22.16
# Epoch 11/500: Lowest Loss = 0.00046032, Accuracy = 22.38
# Epoch 12/500: Lowest Loss = 0.00046032, Accuracy = 23.30
# Epoch 13/500: Lowest Loss = 0.00046030, Accuracy = 23.68
# Epoch 14/500: Lowest Loss = 0.00046032, Accuracy = 23.52
# Epoch 15/500: Lowest Loss = 0.00046030, Accuracy = 23.06
# Epoch 16/500: Lowest Loss = 0.00046030, Accuracy = 24.10
# Epoch 17/500: Lowest Loss = 0.00046031, Accuracy = 23.74
# Epoch 18/500: Lowest Loss = 0.00046033, Accuracy = 24.92
# Epoch 19/500: Lowest Loss = 0.00046031, Accuracy = 23.66
# Epoch 20/500: Lowest Loss = 0.00046032, Accuracy = 24.12
# Epoch 21/500: Lowest Loss = 0.00046033, Accuracy = 24.40
# Epoch 22/500: Lowest Loss = 0.00046037, Accuracy = 24.42
# Epoch 23/500: Lowest Loss = 0.00046034, Accuracy = 24.84
# Epoch 24/500: Lowest Loss = 0.00046035, Accuracy = 24.34
# Epoch 25/500: Lowest Loss = 0.00046039, Accuracy = 24.38
# Epoch 26/500: Lowest Loss = 0.00046033, Accuracy = 24.28
# Epoch 27/500: Lowest Loss = 0.00046038, Accuracy = 24.52
# Epoch 28/500: Lowest Loss = 0.00046035, Accuracy = 24.54
# Epoch 29/500: Lowest Loss = 0.00046035, Accuracy = 24.58
# Epoch 30/500: Lowest Loss = 0.00046033, Accuracy = 25.22
# Epoch 31/500: Lowest Loss = 0.00046030, Accuracy = 25.00
# Epoch 32/500: Lowest Loss = 0.00046032, Accuracy = 25.92
# Epoch 33/500: Lowest Loss = 0.00046028, Accuracy = 26.80
# Epoch 34/500: Lowest Loss = 0.00046030, Accuracy = 25.92
# Epoch 35/500: Lowest Loss = 0.00046020, Accuracy = 27.48
# Epoch 36/500: Lowest Loss = 0.00046024, Accuracy = 26.74
# Epoch 37/500: Lowest Loss = 0.00046018, Accuracy = 28.54
# Epoch 38/500: Lowest Loss = 0.00046020, Accuracy = 29.18
# Epoch 39/500: Lowest Loss = 0.00046022, Accuracy = 28.86
# Epoch 40/500: Lowest Loss = 0.00046017, Accuracy = 30.08
# Epoch 41/500: Lowest Loss = 0.00046020, Accuracy = 27.94
# Epoch 42/500: Lowest Loss = 0.00046018, Accuracy = 28.18
# Epoch 43/500: Lowest Loss = 0.00046019, Accuracy = 28.38
# Epoch 44/500: Lowest Loss = 0.00046018, Accuracy = 28.52
# Epoch 45/500: Lowest Loss = 0.00046021, Accuracy = 28.34
# Epoch 46/500: Lowest Loss = 0.00046022, Accuracy = 27.56
# Epoch 47/500: Lowest Loss = 0.00046021, Accuracy = 28.70
# Epoch 48/500: Lowest Loss = 0.00046020, Accuracy = 28.78
# Epoch 49/500: Lowest Loss = 0.00046020, Accuracy = 29.02
# Epoch 50/500: Lowest Loss = 0.00046017, Accuracy = 30.22
# TEST RESULTS: Epoch 50/500: Lowest Loss = 0.00023009, Accuracy = 29.47
# Epoch 51/500: Lowest Loss = 0.00046017, Accuracy = 30.64
# Epoch 52/500: Lowest Loss = 0.00046018, Accuracy = 29.64
# Epoch 53/500: Lowest Loss = 0.00046018, Accuracy = 29.32
# Epoch 54/500: Lowest Loss = 0.00046018, Accuracy = 29.06
# Epoch 55/500: Lowest Loss = 0.00046019, Accuracy = 29.60
# Epoch 56/500: Lowest Loss = 0.00046019, Accuracy = 29.78
# Epoch 57/500: Lowest Loss = 0.00046016, Accuracy = 30.20
# Epoch 58/500: Lowest Loss = 0.00046015, Accuracy = 29.80
# Epoch 59/500: Lowest Loss = 0.00046015, Accuracy = 30.54
# Epoch 60/500: Lowest Loss = 0.00046010, Accuracy = 31.58
# Epoch 61/500: Lowest Loss = 0.00046010, Accuracy = 31.32
# Epoch 62/500: Lowest Loss = 0.00046008, Accuracy = 30.56
# Epoch 63/500: Lowest Loss = 0.00046016, Accuracy = 31.98
# Epoch 64/500: Lowest Loss = 0.00046007, Accuracy = 31.02
# Epoch 65/500: Lowest Loss = 0.00046017, Accuracy = 31.10
# Epoch 66/500: Lowest Loss = 0.00046018, Accuracy = 30.34
# Epoch 67/500: Lowest Loss = 0.00046017, Accuracy = 30.16
# Epoch 68/500: Lowest Loss = 0.00046017, Accuracy = 29.62
# Epoch 69/500: Lowest Loss = 0.00046011, Accuracy = 30.62
# Epoch 70/500: Lowest Loss = 0.00046016, Accuracy = 31.46
# Epoch 71/500: Lowest Loss = 0.00046017, Accuracy = 30.82
# Epoch 72/500: Lowest Loss = 0.00046018, Accuracy = 30.08
# Epoch 73/500: Lowest Loss = 0.00046018, Accuracy = 30.20
# Epoch 74/500: Lowest Loss = 0.00046018, Accuracy = 30.84
# Epoch 75/500: Lowest Loss = 0.00046014, Accuracy = 31.14
# Epoch 76/500: Lowest Loss = 0.00046017, Accuracy = 31.84
# Epoch 77/500: Lowest Loss = 0.00046020, Accuracy = 29.68
# Epoch 78/500: Lowest Loss = 0.00046012, Accuracy = 31.34
# Epoch 79/500: Lowest Loss = 0.00046011, Accuracy = 31.72
# Epoch 80/500: Lowest Loss = 0.00046009, Accuracy = 31.40
# Epoch 81/500: Lowest Loss = 0.00046011, Accuracy = 31.12
# Epoch 82/500: Lowest Loss = 0.00046013, Accuracy = 30.68
# Epoch 83/500: Lowest Loss = 0.00046010, Accuracy = 31.28
# Epoch 84/500: Lowest Loss = 0.00046011, Accuracy = 32.00
# Epoch 85/500: Lowest Loss = 0.00046012, Accuracy = 31.10
# Epoch 86/500: Lowest Loss = 0.00046012, Accuracy = 31.32
# Epoch 87/500: Lowest Loss = 0.00046011, Accuracy = 30.14
# Epoch 88/500: Lowest Loss = 0.00046015, Accuracy = 31.08
# Epoch 89/500: Lowest Loss = 0.00046013, Accuracy = 30.98
# Epoch 90/500: Lowest Loss = 0.00046010, Accuracy = 31.32
# Epoch 91/500: Lowest Loss = 0.00046012, Accuracy = 32.16
# Epoch 92/500: Lowest Loss = 0.00046009, Accuracy = 31.88
# Epoch 93/500: Lowest Loss = 0.00046012, Accuracy = 31.26
# Epoch 94/500: Lowest Loss = 0.00046009, Accuracy = 31.64
# Epoch 95/500: Lowest Loss = 0.00046011, Accuracy = 31.88
# Epoch 96/500: Lowest Loss = 0.00046013, Accuracy = 31.66
# Epoch 97/500: Lowest Loss = 0.00046013, Accuracy = 31.22
# Epoch 98/500: Lowest Loss = 0.00046015, Accuracy = 30.88
# Epoch 99/500: Lowest Loss = 0.00046007, Accuracy = 33.16
# Epoch 100/500: Lowest Loss = 0.00046011, Accuracy = 31.84
# TEST RESULTS: Epoch 100/500: Lowest Loss = 0.00023007, Accuracy = 31.60
# Epoch 101/500: Lowest Loss = 0.00046012, Accuracy = 31.72
# Epoch 102/500: Lowest Loss = 0.00046013, Accuracy = 31.58
# Epoch 103/500: Lowest Loss = 0.00046012, Accuracy = 30.52
# Epoch 104/500: Lowest Loss = 0.00046013, Accuracy = 30.60
# Epoch 105/500: Lowest Loss = 0.00046011, Accuracy = 31.14
# Epoch 106/500: Lowest Loss = 0.00046015, Accuracy = 30.26
# Epoch 107/500: Lowest Loss = 0.00046016, Accuracy = 30.36
# Epoch 108/500: Lowest Loss = 0.00046013, Accuracy = 30.70
# Epoch 109/500: Lowest Loss = 0.00046013, Accuracy = 31.94
# Epoch 110/500: Lowest Loss = 0.00046009, Accuracy = 31.12
# Epoch 111/500: Lowest Loss = 0.00046005, Accuracy = 31.96
# Epoch 112/500: Lowest Loss = 0.00046004, Accuracy = 32.06
# Epoch 113/500: Lowest Loss = 0.00046013, Accuracy = 31.94
# Epoch 114/500: Lowest Loss = 0.00046006, Accuracy = 31.20
# Epoch 115/500: Lowest Loss = 0.00046012, Accuracy = 31.68
# Epoch 116/500: Lowest Loss = 0.00046013, Accuracy = 31.86
# Epoch 117/500: Lowest Loss = 0.00046012, Accuracy = 31.84
# Epoch 118/500: Lowest Loss = 0.00046013, Accuracy = 31.06
# Epoch 119/500: Lowest Loss = 0.00046011, Accuracy = 31.64
# Epoch 120/500: Lowest Loss = 0.00046017, Accuracy = 30.78
# Epoch 121/500: Lowest Loss = 0.00046016, Accuracy = 31.30
# Epoch 122/500: Lowest Loss = 0.00046018, Accuracy = 30.80
# Epoch 123/500: Lowest Loss = 0.00046018, Accuracy = 30.54
# Epoch 124/500: Lowest Loss = 0.00046016, Accuracy = 31.28
# Epoch 125/500: Lowest Loss = 0.00046016, Accuracy = 31.22
# Epoch 126/500: Lowest Loss = 0.00046016, Accuracy = 30.52
# Epoch 127/500: Lowest Loss = 0.00046017, Accuracy = 30.94
# Epoch 128/500: Lowest Loss = 0.00046013, Accuracy = 31.62
# Epoch 129/500: Lowest Loss = 0.00046013, Accuracy = 30.16
# Epoch 130/500: Lowest Loss = 0.00046019, Accuracy = 30.82
# Epoch 131/500: Lowest Loss = 0.00046019, Accuracy = 29.88
# Epoch 132/500: Lowest Loss = 0.00046017, Accuracy = 30.90
# Epoch 133/500: Lowest Loss = 0.00046017, Accuracy = 30.48
# Epoch 134/500: Lowest Loss = 0.00046018, Accuracy = 30.22
# Epoch 135/500: Lowest Loss = 0.00046017, Accuracy = 29.88
# Epoch 136/500: Lowest Loss = 0.00046016, Accuracy = 30.58
# Epoch 137/500: Lowest Loss = 0.00046018, Accuracy = 29.96
# Epoch 138/500: Lowest Loss = 0.00046020, Accuracy = 30.18
# Epoch 139/500: Lowest Loss = 0.00046019, Accuracy = 30.02
# Epoch 140/500: Lowest Loss = 0.00046014, Accuracy = 29.56
# Epoch 141/500: Lowest Loss = 0.00046017, Accuracy = 31.34
# Epoch 142/500: Lowest Loss = 0.00046015, Accuracy = 31.70
# Epoch 143/500: Lowest Loss = 0.00046018, Accuracy = 31.36
# Epoch 144/500: Lowest Loss = 0.00046011, Accuracy = 31.66
# Epoch 145/500: Lowest Loss = 0.00046012, Accuracy = 31.32
# Epoch 146/500: Lowest Loss = 0.00046012, Accuracy = 31.62
# Epoch 147/500: Lowest Loss = 0.00046011, Accuracy = 31.94
# Epoch 148/500: Lowest Loss = 0.00046018, Accuracy = 31.36
# Epoch 149/500: Lowest Loss = 0.00046014, Accuracy = 32.40
# Epoch 150/500: Lowest Loss = 0.00046017, Accuracy = 31.92
# TEST RESULTS: Epoch 150/500: Lowest Loss = 0.00023009, Accuracy = 30.72
# Epoch 151/500: Lowest Loss = 0.00046016, Accuracy = 31.28
# Epoch 152/500: Lowest Loss = 0.00046014, Accuracy = 32.00
# Epoch 153/500: Lowest Loss = 0.00046018, Accuracy = 31.42
# Epoch 154/500: Lowest Loss = 0.00046017, Accuracy = 31.88
# Epoch 155/500: Lowest Loss = 0.00046019, Accuracy = 30.52
# Epoch 156/500: Lowest Loss = 0.00046017, Accuracy = 30.96
# Epoch 157/500: Lowest Loss = 0.00046017, Accuracy = 31.62
# Epoch 158/500: Lowest Loss = 0.00046018, Accuracy = 30.98
# Epoch 159/500: Lowest Loss = 0.00046018, Accuracy = 30.82
# Epoch 160/500: Lowest Loss = 0.00046019, Accuracy = 30.70
# Epoch 161/500: Lowest Loss = 0.00046017, Accuracy = 31.10
# Epoch 162/500: Lowest Loss = 0.00046020, Accuracy = 30.56
# Epoch 163/500: Lowest Loss = 0.00046017, Accuracy = 32.10
# Epoch 164/500: Lowest Loss = 0.00046019, Accuracy = 30.68
# Epoch 165/500: Lowest Loss = 0.00046018, Accuracy = 31.34
# Epoch 166/500: Lowest Loss = 0.00046013, Accuracy = 29.90
# Epoch 167/500: Lowest Loss = 0.00046018, Accuracy = 31.24
# Epoch 168/500: Lowest Loss = 0.00046017, Accuracy = 31.20
# Epoch 169/500: Lowest Loss = 0.00046019, Accuracy = 30.74
# Epoch 170/500: Lowest Loss = 0.00046017, Accuracy = 32.06
# Epoch 171/500: Lowest Loss = 0.00046019, Accuracy = 30.52
# Epoch 172/500: Lowest Loss = 0.00046019, Accuracy = 30.88
# Epoch 173/500: Lowest Loss = 0.00046016, Accuracy = 31.24
# Epoch 174/500: Lowest Loss = 0.00046012, Accuracy = 32.62
# Epoch 175/500: Lowest Loss = 0.00046016, Accuracy = 31.94
# Epoch 176/500: Lowest Loss = 0.00046014, Accuracy = 31.58
# Epoch 177/500: Lowest Loss = 0.00046014, Accuracy = 31.80
# Epoch 178/500: Lowest Loss = 0.00046015, Accuracy = 31.80
# Epoch 179/500: Lowest Loss = 0.00046015, Accuracy = 32.52
# Epoch 180/500: Lowest Loss = 0.00046017, Accuracy = 31.08
# Epoch 181/500: Lowest Loss = 0.00046016, Accuracy = 31.76
# Epoch 182/500: Lowest Loss = 0.00046018, Accuracy = 32.22
# Epoch 183/500: Lowest Loss = 0.00046017, Accuracy = 32.16
# Epoch 184/500: Lowest Loss = 0.00046017, Accuracy = 31.76
# Epoch 185/500: Lowest Loss = 0.00046019, Accuracy = 31.94
# Epoch 186/500: Lowest Loss = 0.00046016, Accuracy = 32.64
# Epoch 187/500: Lowest Loss = 0.00046017, Accuracy = 33.30
# Epoch 188/500: Lowest Loss = 0.00046017, Accuracy = 32.10
# Epoch 189/500: Lowest Loss = 0.00046015, Accuracy = 32.62
# Epoch 190/500: Lowest Loss = 0.00046016, Accuracy = 31.94
# Epoch 191/500: Lowest Loss = 0.00046015, Accuracy = 32.56
# Epoch 192/500: Lowest Loss = 0.00046016, Accuracy = 32.24
# Epoch 193/500: Lowest Loss = 0.00046015, Accuracy = 32.54
# Epoch 194/500: Lowest Loss = 0.00046014, Accuracy = 32.36
# Epoch 195/500: Lowest Loss = 0.00046013, Accuracy = 32.08
# Epoch 196/500: Lowest Loss = 0.00046014, Accuracy = 32.62
# Epoch 197/500: Lowest Loss = 0.00046015, Accuracy = 32.20
# Epoch 198/500: Lowest Loss = 0.00046017, Accuracy = 31.62
# Epoch 199/500: Lowest Loss = 0.00046016, Accuracy = 31.00
# Epoch 200/500: Lowest Loss = 0.00046016, Accuracy = 31.74
# TEST RESULTS: Epoch 200/500: Lowest Loss = 0.00023009, Accuracy = 31.14
# Epoch 201/500: Lowest Loss = 0.00046017, Accuracy = 31.36
# Epoch 202/500: Lowest Loss = 0.00046014, Accuracy = 33.08
# Epoch 203/500: Lowest Loss = 0.00046015, Accuracy = 31.84
# Epoch 204/500: Lowest Loss = 0.00046012, Accuracy = 31.18
# Epoch 205/500: Lowest Loss = 0.00046015, Accuracy = 32.52
# Epoch 206/500: Lowest Loss = 0.00046011, Accuracy = 32.86
# Epoch 207/500: Lowest Loss = 0.00046014, Accuracy = 32.42
# Epoch 208/500: Lowest Loss = 0.00046020, Accuracy = 31.26
# Epoch 209/500: Lowest Loss = 0.00046020, Accuracy = 31.96
# Epoch 210/500: Lowest Loss = 0.00046016, Accuracy = 31.10
# Epoch 211/500: Lowest Loss = 0.00046023, Accuracy = 31.66
# Epoch 212/500: Lowest Loss = 0.00046020, Accuracy = 31.48
# Epoch 213/500: Lowest Loss = 0.00046016, Accuracy = 32.50
# Epoch 214/500: Lowest Loss = 0.00046015, Accuracy = 32.04
# Epoch 215/500: Lowest Loss = 0.00046014, Accuracy = 31.84
# Epoch 216/500: Lowest Loss = 0.00046015, Accuracy = 31.88
# Epoch 217/500: Lowest Loss = 0.00046014, Accuracy = 31.74
# Epoch 218/500: Lowest Loss = 0.00046012, Accuracy = 31.52
# Epoch 219/500: Lowest Loss = 0.00046015, Accuracy = 30.88
# Epoch 220/500: Lowest Loss = 0.00046015, Accuracy = 30.52
# Epoch 221/500: Lowest Loss = 0.00046003, Accuracy = 31.86
# Epoch 222/500: Lowest Loss = 0.00046012, Accuracy = 32.12
# Epoch 223/500: Lowest Loss = 0.00046011, Accuracy = 32.06
# Epoch 224/500: Lowest Loss = 0.00046013, Accuracy = 32.34
# Epoch 225/500: Lowest Loss = 0.00046011, Accuracy = 32.94
# Epoch 226/500: Lowest Loss = 0.00046015, Accuracy = 31.62
# Epoch 227/500: Lowest Loss = 0.00046014, Accuracy = 31.06
# Epoch 228/500: Lowest Loss = 0.00046012, Accuracy = 32.38
# Epoch 229/500: Lowest Loss = 0.00046015, Accuracy = 31.18
# Epoch 230/500: Lowest Loss = 0.00046015, Accuracy = 31.88
# Epoch 231/500: Lowest Loss = 0.00046007, Accuracy = 31.56
# Epoch 232/500: Lowest Loss = 0.00046005, Accuracy = 32.04
# Epoch 233/500: Lowest Loss = 0.00046007, Accuracy = 31.76
# Epoch 234/500: Lowest Loss = 0.00046008, Accuracy = 31.74
# Epoch 235/500: Lowest Loss = 0.00046007, Accuracy = 31.76
# Epoch 236/500: Lowest Loss = 0.00046010, Accuracy = 33.00
# Epoch 237/500: Lowest Loss = 0.00046011, Accuracy = 32.56
# Epoch 238/500: Lowest Loss = 0.00046007, Accuracy = 33.32
# Epoch 239/500: Lowest Loss = 0.00046009, Accuracy = 33.10
# Epoch 240/500: Lowest Loss = 0.00046008, Accuracy = 33.84
# Epoch 241/500: Lowest Loss = 0.00046010, Accuracy = 34.06
# Epoch 242/500: Lowest Loss = 0.00046012, Accuracy = 33.80
# Epoch 243/500: Lowest Loss = 0.00046013, Accuracy = 33.46
# Epoch 244/500: Lowest Loss = 0.00046012, Accuracy = 33.10
# Epoch 245/500: Lowest Loss = 0.00046009, Accuracy = 34.10
# Epoch 246/500: Lowest Loss = 0.00046011, Accuracy = 34.20
# Epoch 247/500: Lowest Loss = 0.00046012, Accuracy = 34.22
# Epoch 248/500: Lowest Loss = 0.00046007, Accuracy = 34.26
# Epoch 249/500: Lowest Loss = 0.00046003, Accuracy = 35.64
# Epoch 250/500: Lowest Loss = 0.00046006, Accuracy = 35.66
# TEST RESULTS: Epoch 250/500: Lowest Loss = 0.00023005, Accuracy = 34.71
# Epoch 251/500: Lowest Loss = 0.00046008, Accuracy = 35.26
# Epoch 252/500: Lowest Loss = 0.00046007, Accuracy = 35.04
# Epoch 253/500: Lowest Loss = 0.00046006, Accuracy = 35.52
# Epoch 254/500: Lowest Loss = 0.00046003, Accuracy = 35.92
# Epoch 255/500: Lowest Loss = 0.00045999, Accuracy = 36.86
# Epoch 256/500: Lowest Loss = 0.00046001, Accuracy = 36.58
# Epoch 257/500: Lowest Loss = 0.00046007, Accuracy = 35.14
# Epoch 258/500: Lowest Loss = 0.00046002, Accuracy = 36.38
# Epoch 259/500: Lowest Loss = 0.00046002, Accuracy = 36.34
# Epoch 260/500: Lowest Loss = 0.00046003, Accuracy = 35.84
# Epoch 261/500: Lowest Loss = 0.00046005, Accuracy = 35.66
# Epoch 262/500: Lowest Loss = 0.00046004, Accuracy = 35.34
# Epoch 263/500: Lowest Loss = 0.00046004, Accuracy = 36.78
# Epoch 264/500: Lowest Loss = 0.00046001, Accuracy = 36.48
# Epoch 265/500: Lowest Loss = 0.00045999, Accuracy = 37.00
# Epoch 266/500: Lowest Loss = 0.00046004, Accuracy = 35.84
# Epoch 267/500: Lowest Loss = 0.00045997, Accuracy = 36.74
# Epoch 268/500: Lowest Loss = 0.00046004, Accuracy = 35.96
# Epoch 269/500: Lowest Loss = 0.00046002, Accuracy = 36.62
# Epoch 270/500: Lowest Loss = 0.00046002, Accuracy = 36.28
# Epoch 271/500: Lowest Loss = 0.00046000, Accuracy = 36.54
# Epoch 272/500: Lowest Loss = 0.00046006, Accuracy = 35.80
# Epoch 273/500: Lowest Loss = 0.00046003, Accuracy = 36.66
# Epoch 274/500: Lowest Loss = 0.00046002, Accuracy = 37.18
# Epoch 275/500: Lowest Loss = 0.00046001, Accuracy = 36.30
# Epoch 276/500: Lowest Loss = 0.00046004, Accuracy = 35.78
# Epoch 277/500: Lowest Loss = 0.00046001, Accuracy = 37.94
# Epoch 278/500: Lowest Loss = 0.00046004, Accuracy = 35.70
# Epoch 279/500: Lowest Loss = 0.00046002, Accuracy = 36.58
# Epoch 280/500: Lowest Loss = 0.00046000, Accuracy = 36.60
# Epoch 281/500: Lowest Loss = 0.00046002, Accuracy = 36.00
# Epoch 282/500: Lowest Loss = 0.00046003, Accuracy = 36.26
# Epoch 283/500: Lowest Loss = 0.00045999, Accuracy = 36.44
# Epoch 284/500: Lowest Loss = 0.00045997, Accuracy = 36.48
# Epoch 285/500: Lowest Loss = 0.00046001, Accuracy = 35.22
# Epoch 286/500: Lowest Loss = 0.00046004, Accuracy = 34.46
# Epoch 287/500: Lowest Loss = 0.00046001, Accuracy = 34.08
# Epoch 288/500: Lowest Loss = 0.00045999, Accuracy = 35.90
# Epoch 289/500: Lowest Loss = 0.00045999, Accuracy = 34.70
# Epoch 290/500: Lowest Loss = 0.00046000, Accuracy = 36.74
# Epoch 291/500: Lowest Loss = 0.00046003, Accuracy = 35.84
# Epoch 292/500: Lowest Loss = 0.00046000, Accuracy = 36.54
# Epoch 293/500: Lowest Loss = 0.00045996, Accuracy = 35.18
# Epoch 294/500: Lowest Loss = 0.00045996, Accuracy = 35.14
# Epoch 295/500: Lowest Loss = 0.00045994, Accuracy = 35.88
# Epoch 296/500: Lowest Loss = 0.00045998, Accuracy = 35.20
# Epoch 297/500: Lowest Loss = 0.00046000, Accuracy = 35.48
# Epoch 298/500: Lowest Loss = 0.00045995, Accuracy = 34.56
# Epoch 299/500: Lowest Loss = 0.00045999, Accuracy = 34.18
# Epoch 300/500: Lowest Loss = 0.00045996, Accuracy = 35.36
# TEST RESULTS: Epoch 300/500: Lowest Loss = 0.00022999, Accuracy = 34.15
# Epoch 301/500: Lowest Loss = 0.00045998, Accuracy = 35.20
# Epoch 302/500: Lowest Loss = 0.00045998, Accuracy = 34.92
# Epoch 303/500: Lowest Loss = 0.00045992, Accuracy = 36.56
# Epoch 304/500: Lowest Loss = 0.00046000, Accuracy = 36.60
# Epoch 305/500: Lowest Loss = 0.00046000, Accuracy = 37.52
# Epoch 306/500: Lowest Loss = 0.00045995, Accuracy = 36.86
# Epoch 307/500: Lowest Loss = 0.00045994, Accuracy = 36.50
# Epoch 308/500: Lowest Loss = 0.00046001, Accuracy = 36.98
# Epoch 309/500: Lowest Loss = 0.00046002, Accuracy = 37.02
# Epoch 310/500: Lowest Loss = 0.00045999, Accuracy = 37.42
# Epoch 311/500: Lowest Loss = 0.00045999, Accuracy = 36.54
# Epoch 312/500: Lowest Loss = 0.00046002, Accuracy = 37.38
# Epoch 313/500: Lowest Loss = 0.00045999, Accuracy = 38.26
# Epoch 314/500: Lowest Loss = 0.00046002, Accuracy = 37.00
# Epoch 315/500: Lowest Loss = 0.00046003, Accuracy = 36.60
# Epoch 316/500: Lowest Loss = 0.00046003, Accuracy = 36.26
# Epoch 317/500: Lowest Loss = 0.00046003, Accuracy = 35.74
# Epoch 318/500: Lowest Loss = 0.00046000, Accuracy = 36.90
# Epoch 319/500: Lowest Loss = 0.00046002, Accuracy = 36.68
# Epoch 320/500: Lowest Loss = 0.00045999, Accuracy = 38.16
# Epoch 321/500: Lowest Loss = 0.00046001, Accuracy = 37.26
# Epoch 322/500: Lowest Loss = 0.00045999, Accuracy = 37.80
# Epoch 323/500: Lowest Loss = 0.00046002, Accuracy = 36.68
# Epoch 324/500: Lowest Loss = 0.00046002, Accuracy = 36.96
# Epoch 325/500: Lowest Loss = 0.00045998, Accuracy = 37.40
# Epoch 326/500: Lowest Loss = 0.00045998, Accuracy = 37.88
# Epoch 327/500: Lowest Loss = 0.00046000, Accuracy = 36.66
# Epoch 328/500: Lowest Loss = 0.00046000, Accuracy = 36.48
# Epoch 329/500: Lowest Loss = 0.00045999, Accuracy = 36.82
# Epoch 330/500: Lowest Loss = 0.00046000, Accuracy = 36.26
# Epoch 331/500: Lowest Loss = 0.00046003, Accuracy = 36.22
# Epoch 332/500: Lowest Loss = 0.00046000, Accuracy = 36.66
# Epoch 333/500: Lowest Loss = 0.00046002, Accuracy = 35.84
# Epoch 334/500: Lowest Loss = 0.00046002, Accuracy = 35.50
# Epoch 335/500: Lowest Loss = 0.00045998, Accuracy = 37.10
# Epoch 336/500: Lowest Loss = 0.00046001, Accuracy = 37.40
# Epoch 337/500: Lowest Loss = 0.00045999, Accuracy = 37.02
# Epoch 338/500: Lowest Loss = 0.00045999, Accuracy = 37.72
# Epoch 339/500: Lowest Loss = 0.00045996, Accuracy = 37.76
# Epoch 340/500: Lowest Loss = 0.00045999, Accuracy = 35.86
# Epoch 341/500: Lowest Loss = 0.00046000, Accuracy = 36.84
# Epoch 342/500: Lowest Loss = 0.00045997, Accuracy = 36.96
# Epoch 343/500: Lowest Loss = 0.00045998, Accuracy = 37.38
# Epoch 344/500: Lowest Loss = 0.00045995, Accuracy = 37.14
# Epoch 345/500: Lowest Loss = 0.00045996, Accuracy = 36.68
# Epoch 346/500: Lowest Loss = 0.00046000, Accuracy = 35.58
# Epoch 347/500: Lowest Loss = 0.00045998, Accuracy = 36.34
# Epoch 348/500: Lowest Loss = 0.00045999, Accuracy = 35.98
# Epoch 349/500: Lowest Loss = 0.00045998, Accuracy = 36.16
# Epoch 350/500: Lowest Loss = 0.00046001, Accuracy = 36.94
# TEST RESULTS: Epoch 350/500: Lowest Loss = 0.00023000, Accuracy = 35.65
# Epoch 351/500: Lowest Loss = 0.00046001, Accuracy = 36.30
# Epoch 352/500: Lowest Loss = 0.00045996, Accuracy = 36.54
# Epoch 353/500: Lowest Loss = 0.00045998, Accuracy = 36.80
# Epoch 354/500: Lowest Loss = 0.00045996, Accuracy = 36.20
# Epoch 355/500: Lowest Loss = 0.00045996, Accuracy = 36.78
# Epoch 356/500: Lowest Loss = 0.00045999, Accuracy = 35.92
# Epoch 357/500: Lowest Loss = 0.00046001, Accuracy = 36.08
# Epoch 358/500: Lowest Loss = 0.00046000, Accuracy = 36.22
# Epoch 359/500: Lowest Loss = 0.00046001, Accuracy = 35.12
# Epoch 360/500: Lowest Loss = 0.00046000, Accuracy = 35.14
# Epoch 361/500: Lowest Loss = 0.00046002, Accuracy = 35.92
# Epoch 362/500: Lowest Loss = 0.00045999, Accuracy = 36.34
# Epoch 363/500: Lowest Loss = 0.00046003, Accuracy = 35.26
# Epoch 364/500: Lowest Loss = 0.00046001, Accuracy = 35.34
# Epoch 365/500: Lowest Loss = 0.00046001, Accuracy = 37.72
# Epoch 366/500: Lowest Loss = 0.00045999, Accuracy = 37.18
# Epoch 367/500: Lowest Loss = 0.00046001, Accuracy = 37.38
# Epoch 368/500: Lowest Loss = 0.00046002, Accuracy = 36.44
# Epoch 369/500: Lowest Loss = 0.00046001, Accuracy = 37.52
# Epoch 370/500: Lowest Loss = 0.00045999, Accuracy = 37.74
# Epoch 371/500: Lowest Loss = 0.00045999, Accuracy = 36.36
# Epoch 372/500: Lowest Loss = 0.00045999, Accuracy = 37.50
# Epoch 373/500: Lowest Loss = 0.00045997, Accuracy = 38.04
# Epoch 374/500: Lowest Loss = 0.00045997, Accuracy = 38.46
# Epoch 375/500: Lowest Loss = 0.00045997, Accuracy = 36.56
# Epoch 376/500: Lowest Loss = 0.00045999, Accuracy = 37.90
# Epoch 377/500: Lowest Loss = 0.00046000, Accuracy = 37.80
# Epoch 378/500: Lowest Loss = 0.00045999, Accuracy = 37.22
# Epoch 379/500: Lowest Loss = 0.00045998, Accuracy = 37.72
# Epoch 380/500: Lowest Loss = 0.00045999, Accuracy = 37.00
# Epoch 381/500: Lowest Loss = 0.00045998, Accuracy = 37.18
# Epoch 382/500: Lowest Loss = 0.00045999, Accuracy = 37.64
# Epoch 383/500: Lowest Loss = 0.00046001, Accuracy = 36.56
# Epoch 384/500: Lowest Loss = 0.00046002, Accuracy = 36.40
# Epoch 385/500: Lowest Loss = 0.00045998, Accuracy = 36.80
# Epoch 386/500: Lowest Loss = 0.00046000, Accuracy = 37.24
# Epoch 387/500: Lowest Loss = 0.00046001, Accuracy = 37.02
# Epoch 388/500: Lowest Loss = 0.00045999, Accuracy = 37.40
# Epoch 389/500: Lowest Loss = 0.00046000, Accuracy = 36.60
# Epoch 390/500: Lowest Loss = 0.00046001, Accuracy = 37.10
# Epoch 391/500: Lowest Loss = 0.00045999, Accuracy = 37.40
# Epoch 392/500: Lowest Loss = 0.00045999, Accuracy = 37.94
# Epoch 393/500: Lowest Loss = 0.00045996, Accuracy = 37.28
# Epoch 394/500: Lowest Loss = 0.00045999, Accuracy = 36.74
# Epoch 395/500: Lowest Loss = 0.00045998, Accuracy = 37.16
# Epoch 396/500: Lowest Loss = 0.00045997, Accuracy = 37.38
# Epoch 397/500: Lowest Loss = 0.00045998, Accuracy = 37.20
# Epoch 398/500: Lowest Loss = 0.00045998, Accuracy = 37.00
# Epoch 399/500: Lowest Loss = 0.00046002, Accuracy = 36.40
# Epoch 400/500: Lowest Loss = 0.00045999, Accuracy = 37.68
# TEST RESULTS: Epoch 400/500: Lowest Loss = 0.00023000, Accuracy = 36.56
# Epoch 401/500: Lowest Loss = 0.00045995, Accuracy = 38.18
# Epoch 402/500: Lowest Loss = 0.00045995, Accuracy = 37.82
# Epoch 403/500: Lowest Loss = 0.00045997, Accuracy = 37.88
# Epoch 404/500: Lowest Loss = 0.00045994, Accuracy = 38.62
# Epoch 405/500: Lowest Loss = 0.00045997, Accuracy = 38.04
# Epoch 406/500: Lowest Loss = 0.00045998, Accuracy = 37.34
# Epoch 407/500: Lowest Loss = 0.00045993, Accuracy = 38.22
# Epoch 408/500: Lowest Loss = 0.00045996, Accuracy = 37.64
# Epoch 409/500: Lowest Loss = 0.00045994, Accuracy = 37.94
# Epoch 410/500: Lowest Loss = 0.00045994, Accuracy = 37.46
# Epoch 411/500: Lowest Loss = 0.00045996, Accuracy = 36.92
# Epoch 412/500: Lowest Loss = 0.00045996, Accuracy = 37.68
# Epoch 413/500: Lowest Loss = 0.00045998, Accuracy = 36.98
# Epoch 414/500: Lowest Loss = 0.00045994, Accuracy = 37.42
# Epoch 415/500: Lowest Loss = 0.00045998, Accuracy = 36.30
# Epoch 416/500: Lowest Loss = 0.00045997, Accuracy = 37.54
# ...
# Epoch 196/500: Lowest Loss = 0.00046043, Accuracy = 32.68
# Epoch 197/500: Lowest Loss = 0.00046044, Accuracy = 32.86
# Epoch 198/500: Lowest Loss = 0.00046043, Accuracy = 33.26
# Epoch 199/500: Lowest Loss = 0.00046043, Accuracy = 33.16
# Epoch 200/500: Lowest Loss = 0.00046043, Accuracy = 33.50
# TEST RESULTS: Epoch 200/500: Lowest Loss = 0.00023022, Accuracy = 33.11
# Epoch 201/500: Lowest Loss = 0.00046043, Accuracy = 33.38
# Epoch 202/500: Lowest Loss = 0.00046043, Accuracy = 32.88
# Epoch 203/500: Lowest Loss = 0.00046043, Accuracy = 34.82
# Epoch 204/500: Lowest Loss = 0.00046043, Accuracy = 34.18
# Epoch 205/500: Lowest Loss = 0.00046043, Accuracy = 34.38
# Epoch 206/500: Lowest Loss = 0.00046043, Accuracy = 34.98
# Epoch 207/500: Lowest Loss = 0.00046043, Accuracy = 34.54
# Epoch 208/500: Lowest Loss = 0.00046043, Accuracy = 34.06
# Epoch 209/500: Lowest Loss = 0.00046043, Accuracy = 34.24
# Epoch 210/500: Lowest Loss = 0.00046043, Accuracy = 34.10
# Epoch 211/500: Lowest Loss = 0.00046042, Accuracy = 34.30
# Epoch 212/500: Lowest Loss = 0.00046043, Accuracy = 32.80
# Epoch 213/500: Lowest Loss = 0.00046043, Accuracy = 33.32
# Epoch 214/500: Lowest Loss = 0.00046043, Accuracy = 32.90
# Epoch 215/500: Lowest Loss = 0.00046043, Accuracy = 33.20
# Epoch 216/500: Lowest Loss = 0.00046043, Accuracy = 32.76
# Epoch 217/500: Lowest Loss = 0.00046044, Accuracy = 33.50
# Epoch 218/500: Lowest Loss = 0.00046044, Accuracy = 33.46
# Epoch 219/500: Lowest Loss = 0.00046043, Accuracy = 33.72
# Epoch 220/500: Lowest Loss = 0.00046042, Accuracy = 35.04
# Epoch 221/500: Lowest Loss = 0.00046043, Accuracy = 35.36
# Epoch 222/500: Lowest Loss = 0.00046043, Accuracy = 34.02
# Epoch 223/500: Lowest Loss = 0.00046042, Accuracy = 35.48
# Epoch 224/500: Lowest Loss = 0.00046042, Accuracy = 35.02
# Epoch 225/500: Lowest Loss = 0.00046042, Accuracy = 34.42
# Epoch 226/500: Lowest Loss = 0.00046042, Accuracy = 34.12
# Epoch 227/500: Lowest Loss = 0.00046042, Accuracy = 35.14
# Epoch 228/500: Lowest Loss = 0.00046042, Accuracy = 36.20
# Epoch 229/500: Lowest Loss = 0.00046042, Accuracy = 35.50
# Epoch 230/500: Lowest Loss = 0.00046042, Accuracy = 35.12
# Epoch 231/500: Lowest Loss = 0.00046042, Accuracy = 34.96
# Epoch 232/500: Lowest Loss = 0.00046042, Accuracy = 34.52
# Epoch 233/500: Lowest Loss = 0.00046042, Accuracy = 34.68
# Epoch 234/500: Lowest Loss = 0.00046042, Accuracy = 36.18
# Epoch 235/500: Lowest Loss = 0.00046043, Accuracy = 36.20
# Epoch 236/500: Lowest Loss = 0.00046042, Accuracy = 36.92
# Epoch 237/500: Lowest Loss = 0.00046042, Accuracy = 36.02
# Epoch 238/500: Lowest Loss = 0.00046042, Accuracy = 35.98
# Epoch 239/500: Lowest Loss = 0.00046042, Accuracy = 36.04
# Epoch 240/500: Lowest Loss = 0.00046043, Accuracy = 35.18
# Epoch 241/500: Lowest Loss = 0.00046043, Accuracy = 35.62
# Epoch 242/500: Lowest Loss = 0.00046042, Accuracy = 36.04
# Epoch 243/500: Lowest Loss = 0.00046043, Accuracy = 35.68
# Epoch 244/500: Lowest Loss = 0.00046043, Accuracy = 35.54
# Epoch 245/500: Lowest Loss = 0.00046042, Accuracy = 36.46
# Epoch 246/500: Lowest Loss = 0.00046042, Accuracy = 37.42
# Epoch 247/500: Lowest Loss = 0.00046042, Accuracy = 36.52
# Epoch 248/500: Lowest Loss = 0.00046042, Accuracy = 35.30
# Epoch 249/500: Lowest Loss = 0.00046042, Accuracy = 36.64
# Epoch 250/500: Lowest Loss = 0.00046042, Accuracy = 36.08
# TEST RESULTS: Epoch 250/500: Lowest Loss = 0.00023021, Accuracy = 36.00
# Epoch 251/500: Lowest Loss = 0.00046043, Accuracy = 36.36
# Epoch 252/500: Lowest Loss = 0.00046042, Accuracy = 37.10
# Epoch 253/500: Lowest Loss = 0.00046043, Accuracy = 36.46
# Epoch 254/500: Lowest Loss = 0.00046043, Accuracy = 35.96
# Epoch 255/500: Lowest Loss = 0.00046042, Accuracy = 37.06
# Epoch 256/500: Lowest Loss = 0.00046043, Accuracy = 36.14
# Epoch 257/500: Lowest Loss = 0.00046043, Accuracy = 36.48
# Epoch 258/500: Lowest Loss = 0.00046042, Accuracy = 36.66
# Epoch 259/500: Lowest Loss = 0.00046042, Accuracy = 35.94
# Epoch 260/500: Lowest Loss = 0.00046041, Accuracy = 35.92
# Epoch 261/500: Lowest Loss = 0.00046042, Accuracy = 34.90
# Epoch 262/500: Lowest Loss = 0.00046042, Accuracy = 36.62
# Epoch 263/500: Lowest Loss = 0.00046041, Accuracy = 36.52
# Epoch 264/500: Lowest Loss = 0.00046041, Accuracy = 35.78
# Epoch 265/500: Lowest Loss = 0.00046040, Accuracy = 37.54
# Epoch 266/500: Lowest Loss = 0.00046040, Accuracy = 36.86
# Epoch 267/500: Lowest Loss = 0.00046041, Accuracy = 36.80
# Epoch 268/500: Lowest Loss = 0.00046041, Accuracy = 37.12
# Epoch 269/500: Lowest Loss = 0.00046040, Accuracy = 37.36
# Epoch 270/500: Lowest Loss = 0.00046040, Accuracy = 36.36
# Epoch 271/500: Lowest Loss = 0.00046040, Accuracy = 37.42
# Epoch 272/500: Lowest Loss = 0.00046041, Accuracy = 37.00
# Epoch 273/500: Lowest Loss = 0.00046040, Accuracy = 36.64
# Epoch 274/500: Lowest Loss = 0.00046041, Accuracy = 37.38
# Epoch 275/500: Lowest Loss = 0.00046040, Accuracy = 37.64
# Epoch 276/500: Lowest Loss = 0.00046042, Accuracy = 36.60
# Epoch 277/500: Lowest Loss = 0.00046040, Accuracy = 37.12
# Epoch 278/500: Lowest Loss = 0.00046040, Accuracy = 36.78
# Epoch 279/500: Lowest Loss = 0.00046039, Accuracy = 38.14
# Epoch 280/500: Lowest Loss = 0.00046040, Accuracy = 36.98
# Epoch 281/500: Lowest Loss = 0.00046040, Accuracy = 37.78
# Epoch 282/500: Lowest Loss = 0.00046040, Accuracy = 38.34
# Epoch 283/500: Lowest Loss = 0.00046040, Accuracy = 38.14
# Epoch 284/500: Lowest Loss = 0.00046040, Accuracy = 37.86
# Epoch 285/500: Lowest Loss = 0.00046040, Accuracy = 38.24
# Epoch 286/500: Lowest Loss = 0.00046041, Accuracy = 37.60
# Epoch 287/500: Lowest Loss = 0.00046040, Accuracy = 37.14
# Epoch 288/500: Lowest Loss = 0.00046041, Accuracy = 36.64
# Epoch 289/500: Lowest Loss = 0.00046042, Accuracy = 37.68
# Epoch 290/500: Lowest Loss = 0.00046042, Accuracy = 36.16
# Epoch 291/500: Lowest Loss = 0.00046042, Accuracy = 36.32
# Epoch 292/500: Lowest Loss = 0.00046042, Accuracy = 36.34
# Epoch 293/500: Lowest Loss = 0.00046042, Accuracy = 35.90
# Epoch 294/500: Lowest Loss = 0.00046042, Accuracy = 37.22
# Epoch 295/500: Lowest Loss = 0.00046042, Accuracy = 36.32
# Epoch 296/500: Lowest Loss = 0.00046042, Accuracy = 36.40
# Epoch 297/500: Lowest Loss = 0.00046042, Accuracy = 36.72
# Epoch 298/500: Lowest Loss = 0.00046042, Accuracy = 36.08
# Epoch 299/500: Lowest Loss = 0.00046044, Accuracy = 35.40
# Epoch 300/500: Lowest Loss = 0.00046043, Accuracy = 34.26
# TEST RESULTS: Epoch 300/500: Lowest Loss = 0.00023021, Accuracy = 35.74
# Epoch 301/500: Lowest Loss = 0.00046044, Accuracy = 34.62
# Epoch 302/500: Lowest Loss = 0.00046043, Accuracy = 35.28
# Epoch 303/500: Lowest Loss = 0.00046043, Accuracy = 34.92
# Epoch 304/500: Lowest Loss = 0.00046043, Accuracy = 34.52
# Epoch 305/500: Lowest Loss = 0.00046043, Accuracy = 35.46
# Epoch 306/500: Lowest Loss = 0.00046043, Accuracy = 35.32
# Epoch 307/500: Lowest Loss = 0.00046043, Accuracy = 35.64
# Epoch 308/500: Lowest Loss = 0.00046044, Accuracy = 34.12
# Epoch 309/500: Lowest Loss = 0.00046043, Accuracy = 34.86
# Epoch 310/500: Lowest Loss = 0.00046043, Accuracy = 35.02
# Epoch 311/500: Lowest Loss = 0.00046043, Accuracy = 34.88
# Epoch 312/500: Lowest Loss = 0.00046044, Accuracy = 33.66
# Epoch 313/500: Lowest Loss = 0.00046043, Accuracy = 35.22
# Epoch 314/500: Lowest Loss = 0.00046044, Accuracy = 34.38
# Epoch 315/500: Lowest Loss = 0.00046043, Accuracy = 35.18
# Epoch 316/500: Lowest Loss = 0.00046043, Accuracy = 34.70
# Epoch 317/500: Lowest Loss = 0.00046043, Accuracy = 34.10
# Epoch 318/500: Lowest Loss = 0.00046043, Accuracy = 34.80
# Epoch 319/500: Lowest Loss = 0.00046043, Accuracy = 35.96
# Epoch 320/500: Lowest Loss = 0.00046042, Accuracy = 36.04
# Epoch 321/500: Lowest Loss = 0.00046043, Accuracy = 35.18
# Epoch 322/500: Lowest Loss = 0.00046042, Accuracy = 34.60
# Epoch 323/500: Lowest Loss = 0.00046043, Accuracy = 33.82
# Epoch 324/500: Lowest Loss = 0.00046043, Accuracy = 34.88
# Epoch 325/500: Lowest Loss = 0.00046043, Accuracy = 34.84
# Epoch 326/500: Lowest Loss = 0.00046043, Accuracy = 34.14
# Epoch 327/500: Lowest Loss = 0.00046044, Accuracy = 34.86
# Epoch 328/500: Lowest Loss = 0.00046043, Accuracy = 34.90
# Epoch 329/500: Lowest Loss = 0.00046043, Accuracy = 34.28
# Epoch 330/500: Lowest Loss = 0.00046043, Accuracy = 34.38
# Epoch 331/500: Lowest Loss = 0.00046044, Accuracy = 34.06
# Epoch 332/500: Lowest Loss = 0.00046044, Accuracy = 34.54
# Epoch 333/500: Lowest Loss = 0.00046044, Accuracy = 34.28
# Epoch 334/500: Lowest Loss = 0.00046044, Accuracy = 33.66
# Epoch 335/500: Lowest Loss = 0.00046044, Accuracy = 35.78
# Epoch 336/500: Lowest Loss = 0.00046044, Accuracy = 34.48
# Epoch 337/500: Lowest Loss = 0.00046043, Accuracy = 35.56
# Epoch 338/500: Lowest Loss = 0.00046043, Accuracy = 35.86
# Epoch 339/500: Lowest Loss = 0.00046043, Accuracy = 35.62
# Epoch 340/500: Lowest Loss = 0.00046043, Accuracy = 35.92
# Epoch 341/500: Lowest Loss = 0.00046043, Accuracy = 36.30
# Epoch 342/500: Lowest Loss = 0.00046043, Accuracy = 35.80
# Epoch 343/500: Lowest Loss = 0.00046043, Accuracy = 35.70
# Epoch 344/500: Lowest Loss = 0.00046043, Accuracy = 35.78
# Epoch 345/500: Lowest Loss = 0.00046043, Accuracy = 35.74
# Epoch 346/500: Lowest Loss = 0.00046044, Accuracy = 35.12
# Epoch 347/500: Lowest Loss = 0.00046043, Accuracy = 35.86
# Epoch 348/500: Lowest Loss = 0.00046042, Accuracy = 36.24
# Epoch 349/500: Lowest Loss = 0.00046043, Accuracy = 35.12
# Epoch 350/500: Lowest Loss = 0.00046043, Accuracy = 36.12
# TEST RESULTS: Epoch 350/500: Lowest Loss = 0.00023021, Accuracy = 36.34
# Epoch 351/500: Lowest Loss = 0.00046042, Accuracy = 36.86
# Epoch 352/500: Lowest Loss = 0.00046042, Accuracy = 36.26
# Epoch 353/500: Lowest Loss = 0.00046042, Accuracy = 35.74
# Epoch 354/500: Lowest Loss = 0.00046042, Accuracy = 35.18
# Epoch 355/500: Lowest Loss = 0.00046042, Accuracy = 35.88
# Epoch 356/500: Lowest Loss = 0.00046042, Accuracy = 35.00
# Epoch 357/500: Lowest Loss = 0.00046042, Accuracy = 35.36
# Epoch 358/500: Lowest Loss = 0.00046043, Accuracy = 36.44
# Epoch 359/500: Lowest Loss = 0.00046042, Accuracy = 36.56
# Epoch 360/500: Lowest Loss = 0.00046043, Accuracy = 35.88
# Epoch 361/500: Lowest Loss = 0.00046043, Accuracy = 35.54
# Epoch 362/500: Lowest Loss = 0.00046042, Accuracy = 35.98
# Epoch 363/500: Lowest Loss = 0.00046043, Accuracy = 35.94
# Epoch 364/500: Lowest Loss = 0.00046043, Accuracy = 36.40
# Epoch 365/500: Lowest Loss = 0.00046043, Accuracy = 35.74
# Epoch 366/500: Lowest Loss = 0.00046043, Accuracy = 35.52
# Epoch 367/500: Lowest Loss = 0.00046043, Accuracy = 35.26
# Epoch 368/500: Lowest Loss = 0.00046042, Accuracy = 36.04
# Epoch 369/500: Lowest Loss = 0.00046043, Accuracy = 36.14
# Epoch 370/500: Lowest Loss = 0.00046042, Accuracy = 35.92
# Epoch 371/500: Lowest Loss = 0.00046042, Accuracy = 36.12
# Epoch 372/500: Lowest Loss = 0.00046042, Accuracy = 36.02
# Epoch 373/500: Lowest Loss = 0.00046042, Accuracy = 36.22
# Epoch 374/500: Lowest Loss = 0.00046043, Accuracy = 36.10
# Epoch 375/500: Lowest Loss = 0.00046041, Accuracy = 38.14
# Epoch 376/500: Lowest Loss = 0.00046043, Accuracy = 35.52
# Epoch 377/500: Lowest Loss = 0.00046042, Accuracy = 36.84
# Epoch 378/500: Lowest Loss = 0.00046042, Accuracy = 36.52
# Epoch 379/500: Lowest Loss = 0.00046042, Accuracy = 36.48
# Epoch 380/500: Lowest Loss = 0.00046042, Accuracy = 36.06
# Epoch 381/500: Lowest Loss = 0.00046043, Accuracy = 35.74
# Epoch 382/500: Lowest Loss = 0.00046043, Accuracy = 35.28
# Epoch 383/500: Lowest Loss = 0.00046043, Accuracy = 35.78
# Epoch 384/500: Lowest Loss = 0.00046043, Accuracy = 36.58
# Epoch 385/500: Lowest Loss = 0.00046042, Accuracy = 35.54
# Epoch 386/500: Lowest Loss = 0.00046043, Accuracy = 35.96
# Epoch 387/500: Lowest Loss = 0.00046042, Accuracy = 37.62
# Epoch 388/500: Lowest Loss = 0.00046042, Accuracy = 36.32
# Epoch 389/500: Lowest Loss = 0.00046042, Accuracy = 37.10
# Epoch 390/500: Lowest Loss = 0.00046043, Accuracy = 35.78
# Epoch 391/500: Lowest Loss = 0.00046043, Accuracy = 36.20
# Epoch 392/500: Lowest Loss = 0.00046042, Accuracy = 36.92
# Epoch 393/500: Lowest Loss = 0.00046043, Accuracy = 36.56
# Epoch 394/500: Lowest Loss = 0.00046042, Accuracy = 36.42
# Epoch 395/500: Lowest Loss = 0.00046043, Accuracy = 36.28
# Epoch 396/500: Lowest Loss = 0.00046043, Accuracy = 36.16
# Epoch 397/500: Lowest Loss = 0.00046043, Accuracy = 35.84
# Epoch 398/500: Lowest Loss = 0.00046042, Accuracy = 36.66
# Epoch 399/500: Lowest Loss = 0.00046042, Accuracy = 37.82
# Epoch 400/500: Lowest Loss = 0.00046042, Accuracy = 39.24
# TEST RESULTS: Epoch 400/500: Lowest Loss = 0.00023021, Accuracy = 39.70
# Epoch 401/500: Lowest Loss = 0.00046041, Accuracy = 39.14
# Epoch 402/500: Lowest Loss = 0.00046042, Accuracy = 39.06
# Epoch 403/500: Lowest Loss = 0.00046042, Accuracy = 40.02
# Epoch 404/500: Lowest Loss = 0.00046041, Accuracy = 38.56
# Epoch 405/500: Lowest Loss = 0.00046041, Accuracy = 39.02
# Epoch 406/500: Lowest Loss = 0.00046042, Accuracy = 39.46
# Epoch 407/500: Lowest Loss = 0.00046041, Accuracy = 39.14
# Epoch 408/500: Lowest Loss = 0.00046041, Accuracy = 39.42
# Epoch 409/500: Lowest Loss = 0.00046041, Accuracy = 40.02
# Epoch 410/500: Lowest Loss = 0.00046040, Accuracy = 39.26
# Epoch 411/500: Lowest Loss = 0.00046041, Accuracy = 38.30
# Epoch 412/500: Lowest Loss = 0.00046041, Accuracy = 39.62
# Epoch 413/500: Lowest Loss = 0.00046040, Accuracy = 39.68
# Epoch 414/500: Lowest Loss = 0.00046041, Accuracy = 38.72
# Epoch 415/500: Lowest Loss = 0.00046041, Accuracy = 38.98
# Epoch 416/500: Lowest Loss = 0.00046041, Accuracy = 39.04
# Epoch 417/500: Lowest Loss = 0.00046041, Accuracy = 38.52
# Epoch 418/500: Lowest Loss = 0.00046040, Accuracy = 40.26
# Epoch 419/500: Lowest Loss = 0.00046042, Accuracy = 40.02
# Epoch 420/500: Lowest Loss = 0.00046041, Accuracy = 40.02
# Epoch 421/500: Lowest Loss = 0.00046042, Accuracy = 40.52
# Epoch 422/500: Lowest Loss = 0.00046042, Accuracy = 40.80
# Epoch 423/500: Lowest Loss = 0.00046041, Accuracy = 40.18
# Epoch 424/500: Lowest Loss = 0.00046042, Accuracy = 40.42
# Epoch 425/500: Lowest Loss = 0.00046042, Accuracy = 40.36
# Epoch 426/500: Lowest Loss = 0.00046041, Accuracy = 41.28
# Epoch 427/500: Lowest Loss = 0.00046041, Accuracy = 41.24
# Epoch 428/500: Lowest Loss = 0.00046042, Accuracy = 40.94
# Epoch 429/500: Lowest Loss = 0.00046041, Accuracy = 40.76
# Epoch 430/500: Lowest Loss = 0.00046042, Accuracy = 39.72
# Epoch 431/500: Lowest Loss = 0.00046042, Accuracy = 40.38
# Epoch 432/500: Lowest Loss = 0.00046043, Accuracy = 38.98
# Epoch 433/500: Lowest Loss = 0.00046043, Accuracy = 39.42
# Epoch 434/500: Lowest Loss = 0.00046042, Accuracy = 39.96
# Epoch 435/500: Lowest Loss = 0.00046041, Accuracy = 41.04
# Epoch 436/500: Lowest Loss = 0.00046042, Accuracy = 40.26
# Epoch 437/500: Lowest Loss = 0.00046043, Accuracy = 38.54
# Epoch 438/500: Lowest Loss = 0.00046043, Accuracy = 38.96
# Epoch 439/500: Lowest Loss = 0.00046043, Accuracy = 39.24
# Epoch 440/500: Lowest Loss = 0.00046042, Accuracy = 38.88
# Epoch 441/500: Lowest Loss = 0.00046042, Accuracy = 38.84
# Epoch 442/500: Lowest Loss = 0.00046042, Accuracy = 39.48
# Epoch 443/500: Lowest Loss = 0.00046043, Accuracy = 39.22
# Epoch 444/500: Lowest Loss = 0.00046042, Accuracy = 39.90
# Epoch 445/500: Lowest Loss = 0.00046043, Accuracy = 38.96
# Epoch 446/500: Lowest Loss = 0.00046042, Accuracy = 39.90
# Epoch 447/500: Lowest Loss = 0.00046043, Accuracy = 38.26
# Epoch 448/500: Lowest Loss = 0.00046043, Accuracy = 38.72
# Epoch 449/500: Lowest Loss = 0.00046043, Accuracy = 38.90
# Epoch 450/500: Lowest Loss = 0.00046042, Accuracy = 39.94
# TEST RESULTS: Epoch 450/500: Lowest Loss = 0.00023021, Accuracy = 39.93
# Epoch 451/500: Lowest Loss = 0.00046043, Accuracy = 39.32
# Epoch 452/500: Lowest Loss = 0.00046042, Accuracy = 39.44
# Epoch 453/500: Lowest Loss = 0.00046043, Accuracy = 39.46
# Epoch 454/500: Lowest Loss = 0.00046043, Accuracy = 39.02
# Epoch 455/500: Lowest Loss = 0.00046043, Accuracy = 38.30
# Epoch 456/500: Lowest Loss = 0.00046043, Accuracy = 38.50
# Epoch 457/500: Lowest Loss = 0.00046042, Accuracy = 39.50
# Epoch 458/500: Lowest Loss = 0.00046042, Accuracy = 39.22
# Epoch 459/500: Lowest Loss = 0.00046043, Accuracy = 38.96
# Epoch 460/500: Lowest Loss = 0.00046042, Accuracy = 40.48
# Epoch 461/500: Lowest Loss = 0.00046041, Accuracy = 41.32
# Epoch 462/500: Lowest Loss = 0.00046041, Accuracy = 41.32
# Epoch 463/500: Lowest Loss = 0.00046041, Accuracy = 41.94

# %% [markdown]
# Create Plots

# %%
plt.figure(figsize=(10, 6))

ax1 = plt.gca()  # Get current axes for plotting accuracies

for width, all_accuracies in all_accuracies_dict.items():
    # Calculate the average and standard deviation across iterations for each epoch
    avg_accuracies = np.mean(all_accuracies, axis=0)
    std_dev_accuracies = np.std(all_accuracies, axis=0)

    # Plot accuracies with error bars for each width on the primary y-axis
    ax1.errorbar(test_epochs, avg_accuracies, yerr=std_dev_accuracies, label=f'Width {width} Average Accuracy', fmt='-o', capsize=5)

# Labels for the primary y-axis
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.tick_params(axis='y')

# Titles and grids
plt.title('Evolutionary Accuracies vs Epochs')
ax1.legend(loc='upper left')
ax1.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 6))

ax1 = plt.gca()  # Get current axes for plotting accuracies

for width, all_accuracies in all_accuracies_dict.items():
    # Calculate the average and standard deviation across iterations for each epoch
    avg_accuracies = np.mean(all_accuracies, axis=0)
    std_dev_accuracies = np.std(all_accuracies, axis=0)

    # Plot accuracies with error bars for each width on the primary y-axis
    ax1.errorbar(test_epochs, avg_accuracies, yerr=std_dev_accuracies, label=f'Width {width} Average Accuracy', fmt='-o', capsize=5)

# Labels for the primary y-axis
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.tick_params(axis='y')

# Titles and grids
plt.title('Evolutionary Accuracies vs Epochs')
ax1.legend(loc='upper left')
ax1.grid(True)

plt.show()
